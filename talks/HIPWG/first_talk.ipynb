# %%
from IPython.display import display, HTML
display(HTML('input/meeting.html'))
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>meeting</title><script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.10/require.min.js"></script>
# <style type="text/css">
#     pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: var(--jp-cell-editor-active-background) }
# .highlight { background: var(--jp-cell-editor-background); color: var(--jp-mirror-editor-variable-color) }
# ...

# %%
from IPython.display import display, HTML
display(HTML('output/sim_pair_dca_html.html'))
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>sim_pair_dca_html</title><script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.10/require.min.js"></script>
# <style type="text/css">
#     pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: var(--jp-cell-editor-active-background) }
# .highlight { background: var(--jp-cell-editor-background); color: var(--jp-mirror-editor-variable-color) }
# ...

# %%
# %%capture
raise SystemExit("Stopping here!")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stopping here!

# %%
# !jupyter nbconvert --to html second_hit_anime.ipynb --no-input
# !mv second_hit_anime.html input
# Out:
# [NbConvertApp] Converting notebook second_hit_anime.ipynb to html
# [NbConvertApp] Writing 271695 bytes to second_hit_anime.html

# %%
from IPython.display import display, HTML
display(HTML('input/second_hit_anime.html'))
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>second_hit_anime</title><script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.10/require.min.js"></script>
# <style type="text/css">
#     pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: var(--jp-cell-editor-active-background) }
# .highlight { background: var(--jp-cell-editor-background); color: var(--jp-mirror-editor-variable-color) }
# ...

# %%
from IPython.display import display, HTML
display(HTML('association_anime_zoom.html'))
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>association_anime_zoom</title><script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.10/require.min.js"></script>
# <style type="text/css">
#     pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: var(--jp-cell-editor-active-background) }
# .highlight { background: var(--jp-cell-editor-background); color: var(--jp-mirror-editor-variable-color) }
# ...

# %%
from IPython.display import display, Image
display(Image(data=open("output/secondhit.gif",'rb').read(), format='gif'))

# %%
#!jupyter nbconvert --to html first_talk.ipynb --no-input
#!mv first_talk.html output/DCA2.html

# %%
# !jupyter nbconvert --to html ../../pairQA/sim_ddhit_assoc_html.ipynb --no-input
# !mv ../../pairQA/sim_ddhit_assoc_html.html output/sim_ddhit_assoc_html2.html
# Out:
# [NbConvertApp] Converting notebook ../../pairQA/sim_ddhit_assoc_html.ipynb to html
# [NbConvertApp] Writing 426595 bytes to ../../pairQA/sim_ddhit_assoc_html.html

# %%
# !jupyter nbconvert --to html ../../pairQA/sim_pair_dca_html.ipynb --no-input
# !mv ../../pairQA/sim_pair_dca_html.html output/sim_pair_dca_html.html
# Out:
# [NbConvertApp] Converting notebook ../../pairQA/sim_pair_dca_html.ipynb to html
# [NbConvertApp] Writing 321915 bytes to ../../pairQA/sim_pair_dca_html.html

# %%
# !jupyter nbconvert --to html ../../pairQA/hit_assoc_qa_html.ipynb --no-input
# !mv ../../pairQA/hit_assoc_qa_html.html output/hit_assoc_qa_html1.html
# Out:
# [NbConvertApp] Converting notebook ../../pairQA/hit_assoc_qa_html.ipynb to html
# [NbConvertApp] Writing 362306 bytes to ../../pairQA/hit_assoc_qa_html.html

# %%
# !jupyter nbconvert --to html ../meeting_sim.ipynb --no-input
# !mv ../meeting_sim.html output/
# Out:
# [NbConvertApp] Converting notebook ../meeting_sim.ipynb to html
# [NbConvertApp] Writing 590708 bytes to ../meeting_sim.html

# %%
# !jupyter nbconvert --to html ../../m_ee_fit/m_ee_plotter_DCA3.ipynb --no-input
# !mv ../../m_ee_fit/m_ee_plotter_DCA3.html output/noassoc.html
# Out:
# [NbConvertApp] Converting notebook ../../m_ee_fit/m_ee_plotter_DCA3.ipynb to html
# /home/yoren/.local/lib/python3.10/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# [NbConvertApp] Writing 425417 bytes to ../../m_ee_fit/m_ee_plotter_DCA3.html

# %%
# !jupyter nbconvert --to html ../meeting.ipynb --no-input
# !mv ../meeting.html output/DCA.html
# Out:
# [NbConvertApp] Converting notebook ../meeting.ipynb to html
# [NbConvertApp] Writing 298033 bytes to ../meeting.html

# %%
# !jupyter nbconvert --to html htmp_plotter.ipynb --no-input
# !mv htmp_plotter.html output/DCA2.html
# Out:
# [NbConvertApp] Converting notebook htmp_plotter.ipynb to html
# [NbConvertApp] Writing 890282 bytes to htmp_plotter.html
