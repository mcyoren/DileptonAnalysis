# %%
#%%capture
# %run input/Format.ipynb
import ROOT as root
from array import array
root.gErrorIgnoreLevel = root.kFatal
# %jsroot on
# Out:
# /home/yoren/.local/lib/python3.10/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# Welcome to JupyROOT 6.30/06

# %%
iOption0 = 10

# %%
write_html = False
save_to_pdf = False
print_logo = False

# %%
centralities = ["0%-93%","0%-40%","20-40%","40-60%","60-93%","40%-93%"]
Opt_names = ["std", "basic","tight", "std"]
Hists_names = ["m_{ee}_stat","m_{ee}_syst","dca_stat","dca_syst","dca_{J/#Psi}_stat","dca_{J/#Psi}_syst"]
part_names = ["#pi^{0} #rightarrow ee#gamma","#phi #rightarrow ee & #etaee","#phi #rightarrow #etaee","J/#psi  #rightarrow ee",\
              "c#bar{c} #rightarrow ee","b#bar{b} #rightarrow ee","#omega #rightarrow ee & #pi^{0}ee","#omega #rightarrow #pi^{0}ee","QGP",\
              "#eta #rightarrow ee#gamma", "#rho #rightarrow ee","#pi^{-}","#gamma #rightarrow ee","kek"]

# %%
N_centr = 6
N_options = 6
N_pt = 1
colors0=[1,2,root.kGreen+2,4,root.kMagenta,root.kOrange+4,root.kGray,root.kGray,root.kBlack,root.kYellow,root.kViolet,root.kCyan,root.kGreen,root.kOrange]
colors=[2,4,4,root.kGreen+2,root.kOrange+4,root.kMagenta,root.kGray,root.kGray,root.kBlack,root.kCyan,root.kOrange,root.kViolet,root.kCyan,root.kGreen,root.kOrange]
central_bins = [0,20,60,80,20,40,40,60,60,80,80,100]
pt_boarders = [0.4,0.7,1.0,2.0,0,5.0,1.0,5.0,0.5,5]
file_path="input/data/"
file_names=["m_ee_DCA_16.root","m_ee_DCA_17.root","m_ee_DCA_18.root","m_ee_DCA_4.root"]#,"m_ee_DCA_16.root","m_ee_DCA_27.root","m_ee_DCA_23.root","m_ee_DCA_3.root"]#["m_ee_DCA_1.root","m_ee_DCA_3.root"]
sim_file_path="../sim/output/Newembed/invmass/decomposition/HIPWG/"
sim_file_names=['dalitz_50M_v2.root', 'phi_50M_v2.root', "phi_etaee_10M_v1.root", 'jpsi_50M_v4.root', 'ccbar_50M_v0.root', 'bbbar_10M_v1.root',\
                 'omega_10M_v1.root', 'omega_pi0ee_10M_v1.root', 'thermal_25M_v2.root', 'eta_10M_v1.root', 'rho_10M_v1.root', '../bbbar_10M_v0.root']#thermal_25M_200_v0
sim_file_names=['../../../../summer25/invmass/mass/pi0_gee_100M_v03.root', '../../../../summer25/invmass/mass/phi_ee_25M_v01.root', "phi_etaee_10M_v1.root", \
                '../../../../summer25/invmass/mass/jpsi_ee_25M_v06_7.root', '../../../../summer25/invmass/mass/ccbar_sdca_50M_v03.root', '../../../../summer25/invmass/mass/bbbar_10M_v01.root',\
                 'omega_10M_v1.root', 'omega_pi0ee_10M_v1.root', '../../../../summer25/invmass/mass/thermal_sdca_500_50M_v03.root', '../../../../summer25/invmass/mass/eta_gee_50M_v02.root', 'rho_10M_v1.root', '../../../../summer25/invmass/mass/eta_gee_50M_v01.root']#thermal_25M_200_v0
file_order = [0,9, 10, 6, 7, 1, 2, 3, 4, 5, 8]
hist_names = ["inv_mass_stat","inv_mass_syst","dca_stat_0","dca_syst_0","dca_stat_1","dca_syst_1","inv_mass_FG","inv_mass_BG","reb_ratio_FG_BG","syst_reb_ratio_FG_BG","dca_BG_0"]
hist_select_3D_names = ["inv_mass_dca_fg1_6","inv_mass_dca_fg1_5","inv_mass_dca_fg1_6","inv_mass_dca_fg1_7","inv_mass_dca_fg1_8","inv_mass_dca_fg1_9",\
                        "inv_mass_dca_fg2_6","inv_mass_dca_fg2_5","inv_mass_dca_fg2_6","inv_mass_dca_fg2_7","inv_mass_dca_fg2_8","inv_mass_dca_fg2_9",\
                        "inv_mass_dca_fg3_6","inv_mass_dca_fg3_5","inv_mass_dca_fg3_6","inv_mass_dca_fg3_7","inv_mass_dca_fg3_8","inv_mass_dca_fg3_9",\
                        "inv_mass_dca_gen_6","inv_mass_dca_gen_5","inv_mass_dca_gen_6","inv_mass_dca_gen_7","inv_mass_dca_gen_8","inv_mass_dca_gen_9"]
N_type = len(hist_names)
N_hists = len(hist_select_3D_names)

# %%
dNdy = [41.4,0.421,0.759/1000.,0.12,0.01,3.65,10,0.133/1000]
dNdy = [95./257*42.2,0.421,0.421,0.759/1000.,0.12,0.01,3.65,3.65,10,11./257*42.2,8.6*42/257,0.133/1000]
Ncolls = [251,771,282.4,82.6,12.1,40]
Br_to_ee = [1.174e-2, 2.97e-4, 1.08e-4, 5.94e-2, 0.01, 0.01, 7.28e-5, 7.7e-4, 1e-2, 6.9e-3, 4.73e-5, 7.9e-3]
RAA = [[0.4,0.8,0.4,0.4,0.4,0.4,0.4,0.4],[0.3,0.6,0.3,0.3,0.3,0.3,0.3,0.3],[0.4,0.8,0.4,0.4,0.4,0.4,0.4,0.4],[0.8,1.2,0.8,0.8,0.8,0.8,0.8,0.8],[0.9,1.0,0.9,0.9,0.9,0.9,0.9,0.9],[0.9,1.1,0.8,0.9,0.9,0.9,0.9,0.9]]
dNdy_centr = [[dNdy[i]*Ncolls[j]/42.2 for i in range(len(Br_to_ee))] for j in range(6)]

# %%
def copycat_hist(hist,seed=0):
    seed += root.gRandom.Integer(10000)
    new_hist = root.TH3D(hist.GetName()+f"{seed}", hist.GetTitle()+f"{seed}", hist.GetNbinsX(), hist.GetXaxis().GetBinLowEdge(1), hist.GetXaxis().GetBinUpEdge(hist.GetNbinsX()),\
        hist.GetNbinsY(), hist.GetYaxis().GetBinLowEdge(1), hist.GetYaxis().GetBinUpEdge(hist.GetNbinsY()),\
        hist.GetNbinsZ(), hist.GetZaxis().GetBinLowEdge(1), hist.GetZaxis().GetBinUpEdge(hist.GetNbinsZ()))
    for ix in range(1, hist.GetNbinsX()+1):
        for iy in range(1, hist.GetNbinsY()+1):
            for iz in range(1, hist.GetNbinsZ()+1):
                new_hist.SetBinContent(ix, iy, iz, hist.GetBinContent(ix, iy, iz))
    return new_hist

# %%
hists_read = []

for iFile in range(len(file_names)):
    infile = root.TFile.Open(file_path+file_names[iFile], "read")
    hists_emc_read0 = []
    for itype in range(N_type):
        hist_select_3D0 = []
        for icentr in range(N_centr):
            hist_select_3D0.append(infile.Get(hist_names[itype]+f"_{icentr}{0}"))
            try: hist_select_3D0[-1].SetDirectory(root.nullptr)
            except: 
                print(f"Error setting directory for {hist_names[itype]}_{icentr}{0} in file {file_names[iFile]}")
                break
            hist_select_3D0[-1].SetName(hist_select_3D0[-1].GetName()+f"{iFile}")
        hists_emc_read0.append(hist_select_3D0)
    hists_read.append(hists_emc_read0)

    infile.Close()

hists_sim = []

for iFile in range(len(sim_file_names)):
    infile = root.TFile.Open(sim_file_path+sim_file_names[iFile], "read")
    hists_sim_file = []
    for ihist in range(N_hists):
        hists_sim_file.append(infile.Get(hist_select_3D_names[ihist]))
        hists_sim_file[-1].SetDirectory(root.nullptr)
        hists_sim_file[-1].SetName(hists_sim_file[-1].GetName()+f"_sim_{iFile}")
        if ihist%6==0:hists_sim_file[-1].SetName(hists_sim_file[-1].GetName()+f"_sim_{iFile}_{1}")
        if ihist%6==5:hists_sim_file[-1].SetName(hists_sim_file[-1].GetName()+f"_sim_{iFile}_{0}")
    hists_sim.append(hists_sim_file)
    infile.Close()
# Out:
# Error setting directory for dca_stat_1_00 in file m_ee_DCA_4.root
# Error setting directory for dca_syst_1_00 in file m_ee_DCA_4.root

# %%
#conversion crunch:
for ihist in range(18, 24):
    hists_sim[11][ihist].SetEntries(5e7*0.0117/10)

# %%
canvases = []
legends =[]
for ipar in [0,1,5]:
    c0 = root.TCanvas(f"c0_{ipar}",f"c0_{ipar}",1000,1000)
    c0.Divide(1,1)
    canvases.append(c0)
    iOpt = 0
    rebin = 1

    centr_length = [1,0.2/0.93,0.2/0.93,0.2/0.93,0.2/0.93,0.13/0.93]
    for icentr in range(ipar,ipar+1):
        legends.append(root.TLegend(0.2,0.89,0.99,0.97,"Run 2014 "+centralities[icentr]+" Au+Au, #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}}, GeV","dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
        hists_read[iOpt][0][icentr].Draw("")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(1,0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.25,0.83,0.99,0.89,"p_{T}^{e }>0.3 GeV, |y^{e}|<0.35"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()

        #legends[-1].AddEntry(0,"","")
        #legends[-1].AddEntry(hists_read[iOpt][0][icentr],"data","pl")


        #sum_sim_proj.Draw("same L")
        hists_read[iOpt][0][icentr].SetMaximum(2e-4)
        hists_read[iOpt][0][icentr].SetMinimum(1e-10)

    if print_logo: root.PHENIXTools.DrawPreliminary(0.6, 0.6, 0.3)


    # Draw the logo on the canvas with specified coordinates and size
    #logo.DrawImage(0.1, 0.8, 0.3, 0.9)  # Adjust the coordinates and size as needed

    c0.Draw()
    if save_to_pdf:  c0.Print(f"output/Note/mee_prelim.pdf")
    #c0.Print(f"output/Note/mee_prelim.pdf")
# Out:
# <div id="root_plot_1757897823627" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897823627(Core) {
# ...

# %%
canvases = []
legends =[]
for ipar in [0]:#[0,1,5]:
    c0 = root.TCanvas(f"c00_{ipar}",f"c00_{ipar}",1000,1000)
    c0.Divide(1,1)
    canvases.append(c0)
    iOpt = 0
    rebin = 1

    centr_length = [1,0.2/0.93,0.2/0.93,0.2/0.93,0.2/0.93,0.13/0.93]
    for icentr in range(ipar,ipar+1):
        legends.append(root.TLegend(0.2,0.89,0.99,0.97,"Run 2014 "+centralities[icentr]+" Au+Au, #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][6][icentr],"m_{e^{+}e^{-}}, GeV","dN/dm_{e^{+}e^{-}}, GeV^{-1} [In PHENIX Acceptance]",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,4,3,4,0.99,1.55)
        hists_read[iOpt][6][icentr].Draw("")
        hists_read[iOpt][7][icentr].Draw("same")
        Format_Graph(hists_read[iOpt][0][icentr], Mstyle=20,  Msize=1.5,  Mcolor=1,  Lwidth=3,  Lcolor=1,  Malpha=1,  Lalpha=1)
        hists_read[iOpt][0][icentr].Draw("same")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(1,0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.25,0.83,0.99,0.89,"p_{T}^{e }>0.3 GeV, |y^{e}|<0.35"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()

        legends.append(root.TLegend(0.3,0.75,0.7,0.8))
        legends[-1].SetNColumns(3)
        legends[-1].AddEntry(hists_read[iOpt][6][icentr],"FG_{e^{+}e^{-}}","pl")
        legends[-1].AddEntry(hists_read[iOpt][7][icentr],"BG_{e^{+}e^{-}}","pl")
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],"FG_{e^{+}e^{-}}-BG_{e^{+}e^{-}}","pl")
        Format_Legend(legends[-1],0.04)
        legends[-1].Draw()


        #sum_sim_proj.Draw("same L")
        hists_read[iOpt][6][icentr].SetMaximum(2e-3)
        hists_read[iOpt][6][icentr].SetMinimum(1e-10)

    logo = root.TImage.Open("output/phenix_logo.gif")
    pad_logo = root.TPad("logoPad", "Logo Pad", 0.6, 0.6, 0.6 + 0.3, 0.60 + 0.15)
    pad_logo.SetFillStyle(0)
    pad_logo.Draw()
    pad_logo.cd()

    logo.Draw("X"); 

    # Draw the logo on the canvas with specified coordinates and size
    #logo.DrawImage(0.1, 0.8, 0.3, 0.9)  # Adjust the coordinates and size as needed

    c0.Draw()
    if save_to_pdf:  c0.Print(f"output/Note/mee_prelim_bg.pdf")
    #c0.Print(f"output/Note/mee_prelim_bg.png")
# Out:
# <div id="root_plot_1757897823825" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897823825(Core) {
# ...

# %%
iOpt = 0
rebin = 1
legends = []
canvases=[]
centr_length = [1, 0.2 / 0.93, 0.2 / 0.93, 0.2 / 0.93, 0.2 / 0.93, 0.13 / 0.93]
for icentr in [0,1,5]:
    # Create a canvas and divide it into two pads
    c0 = root.TCanvas(f"c5_{icentr}", f"c5_{icentr}", 1000, 1200)
    upper_pad = root.TPad("upper_pad", "Upper Pad", 0, 0.35, 1, 1)
    lower_pad = root.TPad("lower_pad", "Lower Pad", 0, 0, 1, 0.35)
    upper_pad.SetBottomMargin(0.00)
    lower_pad.SetTopMargin(0.00)
    lower_pad.SetBottomMargin(0.3)
    upper_pad.Draw()
    lower_pad.Draw()
    canvases.append(c0)
    upper_pad.cd()
    root.gPad.SetLogy()
    Format_Hist_total(hists_read[iOpt][6][icentr], "m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance", 0.15, 0., 0.01, 0.01, 0.055, 0.055, 21, 1.5, 4, 3, 4, 0.99, 1.35)
    
    hists_read[iOpt][6][icentr].GetXaxis().SetTickLength(0.02)
    hists_read[iOpt][6][icentr].GetYaxis().SetTickLength(0.024)
    hists_read[iOpt][6][icentr].Draw("")
    hists_read[iOpt][7][icentr].Draw("same")
    Format_Graph(hists_read[iOpt][0][icentr], Mstyle=20, Msize=1.5, Mcolor=1, Lwidth=3, Lcolor=1, Malpha=1, Lalpha=1)
    hists_read[iOpt][0][icentr].Draw("same")
    hists_read[iOpt][1][icentr].SetFillColorAlpha(1, 0.4)
    hists_read[iOpt][1][icentr].Draw("same e2")

    legends.append(root.TLegend(0.2, 0.89, 0.99, 0.97, "Run 2014 "+centralities[icentr]+" Au+Au #sqrt{s_{NN}} = 200 GeV"))
    Format_Legend(legends[-1], 0.055, 12)
    legends[-1].Draw()
    legends.append(root.TLegend(0.2, 0.81, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.3 GeV"))
    Format_Legend(legends[-1], 0.055, 12)
    legends[-1].Draw()

    legends.append(root.TLegend(0.3, 0.73, 0.89, 0.81))
    legends[-1].SetNColumns(3)
    legends[-1].AddEntry(hists_read[iOpt][6][icentr], "FG_{+-}", "pl")
    legends[-1].AddEntry(hists_read[iOpt][7][icentr], "BG_{+-}", "pl")
    legends[-1].AddEntry(hists_read[iOpt][0][icentr], "Signal", "pl")
    Format_Legend(legends[-1], 0.055)
    legends[-1].Draw()

    hists_read[iOpt][6][icentr].SetMaximum(2e-3)
    hists_read[iOpt][6][icentr].SetMinimum(1.001e-10)

    # Draw the ratio histogram in the lower pad
    lower_pad.cd()
    lower_pad.SetLogy()

    Format_Hist_total(hists_read[iOpt][8][icentr], "m_{e^{+}e^{-}} (GeV)", "Signal/BG", 0.15, 0.25, 0.01, 0, 0.10, 0.10, 24, 1.5, 1, 3, 1, 0.99, 0.75)
    hists_read[iOpt][8][icentr].SetMinimum(0.011)
    hists_read[iOpt][8][icentr].SetMaximum(200)
    hists_read[iOpt][8][icentr].GetYaxis().ChangeLabel(1,-1,-1,-1,-1,-1,"10^{-1}")
    hists_read[iOpt][8][icentr].GetYaxis().ChangeLabel(2,-1,-1,-1,-1,-1,"10^{0^{  }}")
    hists_read[iOpt][8][icentr].GetYaxis().ChangeLabel(3,-1,-1,-1,-1,-1,"10^{+1}")
    hists_read[iOpt][8][icentr].GetYaxis().ChangeLabel(4,-1,-1,-1,-1,-1,"10^{+2}")
    hists_read[iOpt][8][icentr].GetXaxis().SetNdivisions(505)
    hists_read[iOpt][8][icentr].GetYaxis().SetNdivisions(203)
    hists_read[iOpt][8][icentr].GetXaxis().SetTickLength(0.04)
    hists_read[iOpt][8][icentr].GetYaxis().SetTickLength(0.03)
    hists_read[iOpt][8][icentr].Draw("")
    hists_read[iOpt][9][icentr].SetFillColorAlpha(1, 0.4)
    hists_read[iOpt][9][icentr].Draw("same e2")

    upper_pad.cd()
    if print_logo: root.PHENIXTools.DrawPreliminary(0.2, 0.07, 0.3)

    c0.Draw()
    if save_to_pdf:
        c0.Print(f"output/Note/mee_prelim_bg.pdf")

#c0.Print(f"output/Note/mee_ratio_prelim.pdf")
# Out:
# <div id="root_plot_1757897823961" style="width: 1000px; height: 1200px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897823961(Core) {
# ...

# %%
canvases = []
legends = []
shift = 6
for ipar in [0]:#[0,1,5]:
    c0 = root.TCanvas(f"c1_{ipar}",f"c1_{ipar}",1000,1000)
    c0.Divide(1,1)
    canvases.append(c0)
    iOpt = 0
    rebin = 2
    keffs = [1,2,1,1/2,2e-7,4e-8/4,1,1,2e-7,1,1,1]
    for icentr in range(ipar,1+ipar):
        legends.append(root.TLegend(0.2,0.90,0.99,0.96,"Run 2014 "+centralities[icentr]+" Au+Au #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        legends.append(root.TLegend(0.2, 0.86, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.4 GeV, p_{T}^{ee}>0.8 GeV"))
        Format_Legend(legends[-1],0.04,12)
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
        hists_read[iOpt][0][icentr].SetMaximum(2e-3)
        hists_read[iOpt][0][icentr].SetMinimum(1.001e-10)
        hists_read[iOpt][0][icentr].Draw("")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(1,0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.25,0.86,0.45,0.90))
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],"data","p")
        legends[-1].Draw()
        legends.append(root.TLegend(0.06,0.75,0.65,0.86))
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(0,"p_{T}^{e }>0.3 GeV","")
        legends[-1].AddEntry(0,"|y^{e}|<0.35","")
        legends[-1].Draw()
        legends.append(root.TLegend(0.4,0.56,0.99,0.905))
        Format_Legend(legends[-1],0.035,12)

        sum_sim_proj = hists_sim[len(sim_file_names)-1][icentr].ProjectionY(hists_sim[len(sim_file_names)-1][icentr].GetName()+f"_proj{iOpt}") 
        sum_sim_proj.Scale(0)
        for isim in range(0,len(sim_file_names)-1):
            if isim in [2,6,7,8,10]: continue
            sim_proj = hists_sim[isim][icentr+shift].ProjectionY(hists_sim[isim][icentr+shift].GetName()+f"_proj{isim}{iOpt}",1,80,1,25) 
            sim_proj.Scale(0.)
            h_stat = copycat_hist(hists_sim[isim][icentr+18])
            h_stat.Scale(0.)
            for ihist in range(1,6):
                sim_proj.Add(hists_sim[isim][ihist+shift].ProjectionY(hists_sim[isim][ihist+shift].GetName()+f"_proj{isim}{ihist+shift}{iOpt}",1,80,1,25),
                             10./sim_proj.GetBinWidth(1)*keffs[isim]*0.8)
                h_stat.Add(hists_sim[isim][icentr+ihist+18])
            sim_proj.Scale(1./h_stat.GetEntries())
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim], Lalpha=0.7)
            if isim > 10: sim_proj.Rebin(rebin)
            if not write_html:  print(f"{h_stat.Integral()/h_stat.GetEntries()/Br_to_ee[isim]*10:.2E},",f"{h_stat.Integral()*keffs[isim]/Br_to_ee[isim]/h_stat.GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{h_stat.Integral()*keffs[isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/h_stat.GetEntries()*10*100:.0f}%, {part_names[isim]}")
            if False and not write_html:  print(f"{hists_sim[isim][icentr+18].Integral()/hists_sim[isim][icentr+18].GetEntries()/Br_to_ee[isim]*10:.2E},",f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/hists_sim[isim][icentr+18].GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/hists_sim[isim][icentr+18].GetEntries()*10*100:.0f}%, {part_names[isim]}")
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")

        Format_Graph(sum_sim_proj,21,0,colors[isim+1],3,colors[isim+1], Lalpha=0.7)
        sum_sim_proj.Draw("same H")
        legends[-1].AddEntry(sum_sim_proj,"sum","l")
        #legends[-1].AddEntry(0,"","a")
        Format_Legend(legends[-1],0.04,12)
        legends[-1].SetNColumns(2)
        legends[-1].Draw()

    c0.Draw()
    if save_to_pdf:  c0.Print(f"output/Note/cocktail_2.pdf")
# Out:
# 9.58E+01, 9.58E+01, 9.28E+01 103%, #pi^{0} #rightarrow ee#gamma
# 2.73E+00, 5.45E+00, 2.50E+00 218%, #phi #rightarrow ee & #etaee
# 1.19E-03, 5.97E-04, 4.51E-03 13%, J/#psi  #rightarrow ee
# 2.63E+05, 5.26E-02, 7.14E-01 7%, c#bar{c} #rightarrow ee
# 2.31E+05, 2.31E-03, 5.95E-02 4%, b#bar{b} #rightarrow ee
# 1.29E+01, 1.29E+01, 1.07E+01 120%, #eta #rightarrow ee#gamma
# <div id="root_plot_1757897824839" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897824839(Core) {
# ...

# %%
canvases = []
legends = []
shift = 6
for ipar in [1]:#[0,1,5]:
    c0 = root.TCanvas(f"c1_{ipar}",f"c1_{ipar}",1000,1000)
    c0.Divide(1,1)
    canvases.append(c0)
    iOpt = 0
    rebin = 2
    keffs = [1,1,1,1/2,2e-7,0.e-7,1,1,2e-7,1,1,1]
    for icentr in range(ipar,1+ipar):
        legends.append(root.TLegend(0.2,0.90,0.99,0.96,"Run 2014 "+centralities[icentr]+" Au+Au #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        legends.append(root.TLegend(0.2, 0.86, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.4 GeV, p_{T}^{ee}>0.8 GeV"))
        Format_Legend(legends[-1],0.04,12)
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
        hists_read[iOpt][0][icentr].SetMaximum(2e-3)
        hists_read[iOpt][0][icentr].SetMinimum(1.001e-10)
        hists_read[iOpt][0][icentr].Draw("")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(1,0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.25,0.86,0.45,0.90))
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],"data","p")
        legends[-1].Draw()
        legends.append(root.TLegend(0.06,0.75,0.65,0.86))
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(0,"p_{T}^{e }>0.3 GeV","")
        legends[-1].AddEntry(0,"|y^{e}|<0.35","")
        legends[-1].Draw()
        legends.append(root.TLegend(0.4,0.56,0.99,0.905))
        Format_Legend(legends[-1],0.035,12)

        sum_sim_proj = hists_sim[len(sim_file_names)-1][icentr].ProjectionY(hists_sim[len(sim_file_names)-1][icentr].GetName()+f"_3proj{iOpt}") 
        sum_sim_proj.Scale(0)
        for isim in range(0,len(sim_file_names)-1):
            if isim in [2,6,7,8,10]: continue
            sim_proj = hists_sim[isim][icentr+shift].ProjectionY(hists_sim[isim][icentr+shift].GetName()+f"_3proj{isim}{iOpt}",1,80,1,25) 
            sim_proj.Scale(0.)
            h_stat = copycat_hist(hists_sim[isim][icentr+18])
            h_stat.Scale(0.)
            for ihist in range(1,3):
                sim_proj.Add(hists_sim[isim][ihist+shift].ProjectionY(hists_sim[isim][ihist+shift].GetName()+f"_3proj{isim}{ihist+shift}{iOpt}",1,80,1,25),
                             10./sim_proj.GetBinWidth(1)*keffs[isim])
                h_stat.Add(hists_sim[isim][ihist+18])
            sim_proj.Scale(1./h_stat.GetEntries())
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim], Lalpha=0.7)
            if isim > 10: sim_proj.Rebin(rebin)
            if not write_html:  print(f"{h_stat.Integral()/h_stat.GetEntries()/Br_to_ee[isim]*10:.2E},",f"{h_stat.Integral()*keffs[isim]/Br_to_ee[isim]/h_stat.GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{h_stat.Integral()*keffs[isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/h_stat.GetEntries()*10*100:.0f}%, {part_names[isim]}")
            if False and not write_html:  print(f"{hists_sim[isim][icentr+18].Integral()/hists_sim[isim][icentr+18].GetEntries()/Br_to_ee[isim]*10:.2E},",f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/hists_sim[isim][icentr+18].GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/hists_sim[isim][icentr+18].GetEntries()*10*100:.0f}%, {part_names[isim]}")
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")

        Format_Graph(sum_sim_proj,21,0,colors[isim+1],3,colors[isim+1], Lalpha=0.7)
        sum_sim_proj.Draw("same H")
        legends[-1].AddEntry(sum_sim_proj,"sum","l")
        #legends[-1].AddEntry(0,"","a")
        Format_Legend(legends[-1],0.04,12)
        legends[-1].SetNColumns(2)
        legends[-1].Draw()

    c0.Draw()
    if save_to_pdf:  c0.Print(f"output/Note/cocktail_2.pdf")
# Out:
# 1.86E+02, 1.86E+02, 2.85E+02 65%, #pi^{0} #rightarrow ee#gamma
# 5.68E+00, 5.68E+00, 7.69E+00 74%, #phi #rightarrow ee & #etaee
# 2.10E-03, 1.05E-03, 1.39E-02 8%, J/#psi  #rightarrow ee
# 5.49E+05, 1.10E-01, 2.19E+00 5%, c#bar{c} #rightarrow ee
# 4.72E+05, 0.00E+00, 1.83E-01 0%, b#bar{b} #rightarrow ee
# 2.79E+01, 2.79E+01, 3.30E+01 84%, #eta #rightarrow ee#gamma
# <div id="root_plot_1757897825580" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897825580(Core) {
# ...

# %%
canvases = []
legends = []
shift = 6
for ipar in [5]:#[0,1,5]:
    c0 = root.TCanvas(f"c1_{ipar}",f"c1_{ipar}",1000,1000)
    c0.Divide(1,1)
    canvases.append(c0)
    iOpt = 2
    rebin = 2
    keffs = [1,1.5,1,1/2,2e-7,0.5e-7,1,1,2e-7,1,1,1]
    for icentr in range(ipar,1+ipar):
        legends.append(root.TLegend(0.2,0.90,0.99,0.96,"Run 2014 "+centralities[icentr]+" Au+Au #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        legends.append(root.TLegend(0.2, 0.86, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.4 GeV, p_{T}^{ee}>0.8 GeV"))
        Format_Legend(legends[-1],0.04,12)
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
        hists_read[iOpt][0][icentr].SetMaximum(2e-3)
        hists_read[iOpt][0][icentr].SetMinimum(1.001e-10)
        hists_read[iOpt][0][icentr].Draw("")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(1,0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.25,0.86,0.45,0.90))
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],"data","p")
        legends[-1].Draw()
        legends.append(root.TLegend(0.06,0.75,0.65,0.86))
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(0,"p_{T}^{e }>0.3 GeV","")
        legends[-1].AddEntry(0,"|y^{e}|<0.35","")
        legends[-1].Draw()
        legends.append(root.TLegend(0.4,0.56,0.99,0.905))
        Format_Legend(legends[-1],0.035,12)

        sum_sim_proj = hists_sim[len(sim_file_names)-1][icentr].ProjectionY(hists_sim[len(sim_file_names)-1][icentr].GetName()+f"_pr2oj{iOpt}") 
        sum_sim_proj.Scale(0)
        for isim in range(0,len(sim_file_names)-1):
            if isim in [2,6,7,8,10]: continue
            sim_proj = hists_sim[isim][icentr+shift].ProjectionY(hists_sim[isim][icentr+shift].GetName()+f"_pr2oj{isim}{iOpt}",1,80,1,25) 
            sim_proj.Scale(0.)
            h_stat = copycat_hist(hists_sim[isim][icentr+18])
            h_stat.Scale(0.)
            for ihist in range(3,6):
                sim_proj.Add(hists_sim[isim][ihist+shift].ProjectionY(hists_sim[isim][ihist+shift].GetName()+f"_p2roj{isim}{ihist+shift}{iOpt}",1,80,1,25),
                             10./sim_proj.GetBinWidth(1)*keffs[isim])
                h_stat.Add(hists_sim[isim][ihist+18])
            sim_proj.Scale(1./h_stat.GetEntries())
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim], Lalpha=0.7)
            if isim > 10: sim_proj.Rebin(rebin)
            if not write_html:  print(f"{h_stat.Integral()/h_stat.GetEntries()/Br_to_ee[isim]*10:.2E},",f"{h_stat.Integral()*keffs[isim]/Br_to_ee[isim]/h_stat.GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{h_stat.Integral()*keffs[isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/h_stat.GetEntries()*10*100:.0f}%, {part_names[isim]}")
            if False and not write_html:  print(f"{hists_sim[isim][icentr+18].Integral()/hists_sim[isim][icentr+18].GetEntries()/Br_to_ee[isim]*10:.2E},",f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/hists_sim[isim][icentr+18].GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/hists_sim[isim][icentr+18].GetEntries()*10*100:.0f}%, {part_names[isim]}")
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")

        Format_Graph(sum_sim_proj,21,0,colors[isim+1],3,colors[isim+1], Lalpha=0.7)
        sum_sim_proj.Draw("same H")
        legends[-1].AddEntry(sum_sim_proj,"sum","l")
        #legends[-1].AddEntry(0,"","a")
        Format_Legend(legends[-1],0.04,12)
        legends[-1].SetNColumns(2)
        legends[-1].Draw()

    c0.Draw()
    if save_to_pdf:  c0.Print(f"output/Note/cocktail_2.pdf")
# Out:
# 2.63E+01, 2.63E+01, 1.48E+01 178%, #pi^{0} #rightarrow ee#gamma
# 4.09E-01, 6.13E-01, 3.99E-01 154%, #phi #rightarrow ee & #etaee
# 4.75E-04, 2.38E-04, 7.19E-04 33%, J/#psi  #rightarrow ee
# 4.01E+04, 8.02E-03, 1.14E-01 7%, c#bar{c} #rightarrow ee
# 3.39E+04, 1.69E-03, 9.48E-03 18%, b#bar{b} #rightarrow ee
# 1.29E+00, 1.29E+00, 1.71E+00 75%, #eta #rightarrow ee#gamma
# <div id="root_plot_1757897826336" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897826336(Core) {
# ...

# %%
#root.gSystem.Load("input/logo/PHENIXLogo_hpp.so")

# %%
c0 = root.TCanvas(f"c0",f"c0",1000,1000)
c0.Divide(1,1)
iOpt = 0
rebin = 1
legends =[]
abs_norm_cc = 0.096225 * 1000 / 3500095 / 42 / 10
abs_norm_bb = 0.001102 * 10000 / 2104191 / 42 / 10
shift = 6

print(f"{abs_norm_cc:.2E}",f"{abs_norm_bb:.2E}")
keffs = [[1,1,1,1,abs_norm_cc,abs_norm_bb,1,1,2e-7,1,1],[1,2,2,5e1,1e-7,2e-8,1,1,2e-5,1,1],[1,1,1,7e1,2e-7,2e-8,1,1,0e-6,1,1],\
         [1,1,1,1e2,2e-7,2e-8,1,1,5e-7,1,1],[1,1,1,1e2,2e-7,2e-8,1,1,2e-6,1,1],[1,1,1,5e1,1e-7,2e-8,1,1,3e-7,1,1]]
for icentr in range(0,1):
    legends.append(root.TLegend(0.2,0.90,0.99,0.96,"Run 2014 0%-93% Au+Au #sqrt{s_{NN}} = 200 GeV"))
    Format_Legend(legends[-1],0.04,12)
    legends[-1].Draw()
    legends.append(root.TLegend(0.2, 0.86, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.4 GeV, p_{T}^{ee}>0.8 GeV"))
    Format_Legend(legends[-1],0.04,12)
    #legends[-1].Draw()
    c0.cd(1)
    root.gPad.SetLogy()
    Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
    hists_read[iOpt][0][icentr].Draw("")
    hists_read[iOpt][1][icentr].SetFillColorAlpha(1,0.4)
    hists_read[iOpt][1][icentr].Draw("same e2")
    legends.append(root.TLegend(0.25,0.86,0.45,0.90))
    Format_Legend(legends[-1],0.035,12)
    legends[-1].AddEntry(hists_read[iOpt][0][icentr],"data","p")
    legends[-1].Draw()
    legends.append(root.TLegend(0.04,0.71,0.65,0.86))
    Format_Hist_total(hists_read[iOpt][0][icentr],"m_{e^{+}e^{-}} (GeV)", "dN/dm_{e^{+}e^{-}} (GeV^{-1}) in PHENIX acceptance",0.15,0.15,0.01,0.01,0.05,0.05,21,1.5,1,3,1,0.99,1.55)
    Format_Legend(legends[-1],0.035,12)
    legends[-1].AddEntry(0,"p_{T}^{e }>0.4 GeV","")
    legends[-1].AddEntry(0,"p_{T}^{ee}>0.8 GeV","")
    legends[-1].AddEntry(0,"|y^{e}|<0.35","")
    legends[-1].Draw()
    legends.append(root.TLegend(0.4,0.66,0.99,0.905))
    Format_Legend(legends[-1],0.035,12)

    #legends[-1].AddEntry(0,"","")
    #legends[-1].AddEntry(hists_read[iOpt][0][icentr],"data","pl")

    sum_sim_proj = hists_sim[len(sim_file_names)-1][icentr].ProjectionY(hists_sim[len(sim_file_names)-1][icentr].GetName()+f"_proj{iOpt}") 
    sum_sim_proj.Add(sum_sim_proj,-1)
    for isim in file_order:
        if isim == 5 or isim == 4 or isim == 8: continue
        sim_proj = hists_sim[isim][icentr+shift].ProjectionY(hists_sim[isim][icentr+shift].GetName()+f"_projs{isim}{iOpt}",1,50,3,25) 
        sim_proj.Scale(0.)
        h_stat = copycat_hist(hists_sim[isim][icentr+18])
        h_stat.Scale(0.)
        for ihist in range(1,6):
            sim_proj.Add(hists_sim[isim][icentr+ihist+shift].ProjectionY(hists_sim[isim][icentr+ihist+shift].GetName()+f"_proj{isim}{ihist+shift}{iOpt}",1,50,3,25),
                         10./sim_proj.GetBinWidth(1)*keffs[icentr][isim])
            h_stat.Add(hists_sim[isim][icentr+ihist+18])
        sim_proj.Scale(1./h_stat.GetEntries())
        Format_Graph(sim_proj,21+isim,0,colors[isim],2,colors[isim], Lalpha=0.7)
        if isim == 1 or isim == 3: 
            sim_proj.Rebin(rebin)
            sim_proj.Scale(1./rebin)
        if not write_html:  print(f"{h_stat.Integral()/h_stat.GetEntries()/Br_to_ee[isim]*10:.2E},",f"{h_stat.Integral()*keffs[icentr][isim]/Br_to_ee[isim]/h_stat.GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                             f"{h_stat.Integral()*keffs[icentr][isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/h_stat.GetEntries()*10*100:.0f}%, {part_names[isim]}")
        if False and not write_html:  print(f"{hists_sim[isim][icentr+18].Integral()/hists_sim[isim][icentr+18].GetEntries()/Br_to_ee[isim]*10:.2E},",f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/hists_sim[isim][icentr+18].GetEntries()*10:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                             f"{hists_sim[isim][icentr+18].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]/hists_sim[isim][icentr+18].GetEntries()*10*100:.0f}%, {part_names[isim]}")
        sum_sim_proj.Add(sim_proj,1)
        sim_proj.Draw("same H")
        if isim != 2 and isim != 7: legends[-1].AddEntry(sim_proj,part_names[isim],"l")

    for ibin in range(1,sum_sim_proj.GetNbinsX()+1):
        sum_sim_proj.SetBinError(ibin,( (sum_sim_proj.GetBinContent(ibin)*0.2)**2 + sum_sim_proj.GetBinError(ibin)**2 )**0.5)
    Format_Graph(sum_sim_proj,21,0,root.kViolet,2,root.kViolet, Lalpha=0.7)
    sum_sim_proj.SetFillColorAlpha(root.kViolet,0.6)
    sum_sim_proj.Draw("same e4")
    #sum_sim_proj.Draw("same L")
    hists_read[iOpt][0][icentr].SetMaximum(2e-4)
    hists_read[iOpt][0][icentr].SetMinimum(1.001e-10)
    #hists_read[iOpt][0][icentr].SetMaximum(2e-3)
    #hists_read[iOpt][0][icentr].SetMinimum(1e-10)
    #legends[-1].AddEntry(0,"(LO pythia8)","")
    #legends[-1].AddEntry(0,"(LO pythia8)","")
    #legends[-1].AddEntry(sum_sim_proj,"cocktail","f")
    legends[-1].AddEntry(sum_sim_proj,"#splitline{hadronic}{cocktail}","f")
    #legends[-1].AddEntry(0,"","a")
    legends[-1].SetNColumns(2)
    legends[-1].Draw()
    
if print_logo: root.PHENIXTools.DrawPreliminary(0.65, 0.56, 0.3)

#c0.Draw()
if save_to_pdf:  c0.Print(f"output/Note/cocktail_2.pdf")
#c0.Print(f"output/Note/hadronic_cocktail.pdf")
# Out:
# 6.55E-08 1.25E-08
# 9.58E+01, 9.58E+01, 9.28E+01 103%, #pi^{0} #rightarrow ee#gamma
# 1.29E+01, 1.29E+01, 1.07E+01 120%, #eta #rightarrow ee#gamma
# 1.32E+01, 1.32E+01, 8.36E+00 158%, #rho #rightarrow ee
# 1.18E+01, 1.18E+01, 2.17E+01 54%, #omega #rightarrow ee & #pi^{0}ee
# 1.17E+01, 1.17E+01, 2.17E+01 54%, #omega #rightarrow #pi^{0}ee
# 2.73E+00, 2.73E+00, 2.50E+00 109%, #phi #rightarrow ee & #etaee
# 2.70E+00, 2.70E+00, 2.50E+00 108%, #phi #rightarrow #etaee
# 1.19E-03, 1.19E-03, 4.51E-03 26%, J/#psi  #rightarrow ee

# %%
c0 = root.TCanvas(f"c0",f"c0",1000,1000)
skip_thermal = 0
sim_dca = [3,4,5,8]
legends =[]
iOpt = 1
add_bg = 1
shift = 6
keffs = [1,1,1,1,2e-7,0.5e-7,1,1,3e-7,1,1,1]
for icentr in range(5,6):

    legends.append(root.TLegend(0.5,0.65,0.98,0.98,centralities[icentr]))
    for ihist in range(2,3):
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][ihist][icentr],"DCA_T^{e^{+}e^{-}} (#mum)", "dN/DCA_{T}^{e^{+}e^{-}} (#mum^{-1}) in PHENIX acceptance",0.17,0.17,0.01,0.01,0.05,0.05,21,1.5,4,3,4,0.99,1.55)
        hists_read[iOpt][ihist][icentr].GetXaxis().SetRangeUser(0,1000)
        hists_read[iOpt][ihist][icentr].GetYaxis().SetRangeUser(2e-14,9e-8)
        hists_read[iOpt][ihist][icentr].Draw("")
        hists_read[iOpt][ihist+1][icentr].SetFillColorAlpha(4,0.6)
        hists_read[iOpt][ihist+1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.2,0.91,0.99,0.98,"Run 2014 "+centralities[icentr]+" Au+Au #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        legends.append(root.TLegend(0.2, 0.86, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.4 GeV, p_{T}^{ee}>0.8 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends.append(root.TLegend(0.16,0.83,0.65,0.95))
        Format_Legend(legends[-1],0.045,12)
        legends[-1].SetNColumns(2)
        legends[-1].AddEntry(hists_read[iOpt][ihist][icentr],"FG-0.97#timesBG","p")
        legends[-1].AddEntry(hists_read[iOpt][10][icentr],"0.03#timesBG","p")
        legends[-1].Draw()
        legends.append(root.TLegend(0.33,0.74,0.6,0.86))
        Format_Hist_total(hists_read[iOpt][ihist][icentr],"DCA_{T}^{e^{+}e^{-}} (#mum)", "dN/DCA_{T}^{e^{+}e^{-}} (#mum^{-1}) in acceptance",0.17,0.17,0.01,0.01,0.05,0.05,21,1.5,4,3,4,0.99,1.65)
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(0,"1.5<|m_{ee}|<2.5","")
        legends[-1].AddEntry(0,"|y^{e}|<0.35","")
        legends[-1].Draw()
        legends.append(root.TLegend(0.6,0.64+0.06*skip_thermal,0.99,0.90))
        Format_Legend(legends[-1],0.035,12)


        sum_sim_proj = hists_sim[isim][icentr].ProjectionX(hists_sim[len(sim_file_names)-1][icentr].GetName()+"_proj_dca_tot_new") 
        sum_sim_proj.Add(sum_sim_proj,-1)
        for isim in sim_dca:
            if skip_thermal and isim == 8: continue
            sim_proj = hists_sim[isim][icentr].ProjectionX(hists_sim[isim][icentr].GetName()+"_proj_new_dca",25,55,1,25) 
            sim_proj.Scale(0.)
            h_stat = copycat_hist(hists_sim[isim][icentr+18])
            h_stat.Scale(0.)
            for jsim in range(3,6):
                sim_proj.Add(hists_sim[isim][shift+jsim].ProjectionX(hists_sim[isim][shift+jsim].GetName()+f"_proj_new_{isim}{iOpt}",23,55,1,25),
                             10./sim_proj.GetBinWidth(1)*keffs[isim])
                h_stat.Add(hists_sim[isim][jsim+18])
            sim_proj.Scale(1./h_stat.GetEntries())
            #sim_proj.Scale(10./sim_proj.GetBinWidth(1)/hists_sim[isim][icentr+18].GetEntries()*keffs[icentr][isim])
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim])
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")
        
        if add_bg:
            Format_Graph(hists_read[iOpt][10][icentr],21,1.5,root.kCyan,3,root.kCyan)
            hists_read[iOpt][10][icentr].Draw("same")
            #sum_sim_proj.Add(hists_read[iOpt][9][icentr],1)
            for ibin in range(1,sum_sim_proj.GetNbinsX()+1):
                jbin = hists_read[iOpt][10][icentr].FindBin(sum_sim_proj.GetBinCenter(ibin))
                bin_additive= hists_read[iOpt][10][icentr].GetBinContent(jbin)#/hists_read[iOpt][10][icentr].GetBinWidth(jbin)*sum_sim_proj.GetBinWidth(ibin)
                sum_sim_proj.SetBinContent(ibin,sum_sim_proj.GetBinContent(ibin)+bin_additive)
        Format_Graph(sum_sim_proj,21,0,2,3,2)
        for ibin in range(1,sum_sim_proj.GetNbinsX()+1):
            sum_sim_proj.SetBinError(ibin, 0.1*sum_sim_proj.GetBinContent(ibin))
        sum_sim_proj.Draw("same H")
        legends[-1].AddEntry(sum_sim_proj,"sum+BG","l")
        Format_Legend(legends[-1],0.08)
        legends[-1].Draw()

if not write_html:c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757897827827" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897827827(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1000,1000)
skip_thermal = 0
sim_dca = [3,4,5,8]
legends =[]
iOpt = 1
add_bg = 1
shift = 6
keffs = [1,1,1,1,2e-7,0.5e-7,1,1,3e-7,1,1,1]
for icentr in range(0,1):

    legends.append(root.TLegend(0.5,0.65,0.98,0.98,centralities[icentr]))
    for ihist in range(2,3):
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][ihist][icentr],"DCA_T^{e^{+}e^{-}} (#mum)", "dN/DCA_{T}^{e^{+}e^{-}} (#mum^{-1}) in PHENIX acceptance",0.17,0.17,0.01,0.01,0.05,0.05,21,1.5,4,3,4,0.99,1.55)
        hists_read[iOpt][ihist][icentr].GetXaxis().SetRangeUser(0,1000)
        hists_read[iOpt][ihist][icentr].GetYaxis().SetRangeUser(2e-14,9e-8)
        hists_read[iOpt][ihist][icentr].Draw("")
        hists_read[iOpt][ihist+1][icentr].SetFillColorAlpha(4,0.6)
        hists_read[iOpt][ihist+1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.2,0.91,0.99,0.98,"Run 2014 "+centralities[icentr]+" Au+Au #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        legends.append(root.TLegend(0.2, 0.86, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.4 GeV, p_{T}^{ee}>0.8 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends.append(root.TLegend(0.16,0.83,0.65,0.95))
        Format_Legend(legends[-1],0.045,12)
        legends[-1].SetNColumns(2)
        legends[-1].AddEntry(hists_read[iOpt][ihist][icentr],"FG-0.97#timesBG","p")
        legends[-1].AddEntry(hists_read[iOpt][10][icentr],"0.03#timesBG","p")
        legends[-1].Draw()
        legends.append(root.TLegend(0.33,0.74,0.6,0.86))
        Format_Hist_total(hists_read[iOpt][ihist][icentr],"DCA_{T}^{e^{+}e^{-}} (#mum)", "dN/DCA_{T}^{e^{+}e^{-}} (#mum^{-1}) in acceptance",0.17,0.17,0.01,0.01,0.05,0.05,21,1.5,4,3,4,0.99,1.65)
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(0,"1.5<|m_{ee}|<2.5","")
        legends[-1].AddEntry(0,"|y^{e}|<0.35","")
        legends[-1].Draw()
        legends.append(root.TLegend(0.6,0.64+0.06*skip_thermal,0.99,0.90))
        Format_Legend(legends[-1],0.035,12)


        sum_sim_proj = hists_sim[isim][icentr].ProjectionX(hists_sim[len(sim_file_names)-1][icentr].GetName()+"_proj1_dca_tot_new") 
        sum_sim_proj.Add(sum_sim_proj,-1)
        for isim in sim_dca:
            if skip_thermal and isim == 8: continue
            sim_proj = hists_sim[isim][icentr].ProjectionX(hists_sim[isim][icentr].GetName()+"_proj1_new_dca",23,55,1,25) 
            sim_proj.Scale(0.)
            h_stat = copycat_hist(hists_sim[isim][icentr+18])
            h_stat.Scale(0.)
            for jsim in range(1,6):
                sim_proj.Add(hists_sim[isim][shift+jsim].ProjectionX(hists_sim[isim][shift+jsim].GetName()+f"_proj1_new_{isim}{iOpt}",23,55,1,25),
                             10./sim_proj.GetBinWidth(1)*keffs[isim])
                h_stat.Add(hists_sim[isim][jsim+18])
            sim_proj.Scale(1./h_stat.GetEntries())
            #sim_proj.Scale(10./sim_proj.GetBinWidth(1)/hists_sim[isim][icentr+18].GetEntries()*keffs[icentr][isim])
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim])
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")
        
        if add_bg:
            Format_Graph(hists_read[iOpt][10][icentr],21,1.5,root.kCyan,3,root.kCyan)
            hists_read[iOpt][10][icentr].Draw("same")
            #sum_sim_proj.Add(hists_read[iOpt][9][icentr],1)
            for ibin in range(1,sum_sim_proj.GetNbinsX()+1):
                jbin = hists_read[iOpt][10][icentr].FindBin(sum_sim_proj.GetBinCenter(ibin))
                bin_additive= hists_read[iOpt][10][icentr].GetBinContent(jbin)#/hists_read[iOpt][10][icentr].GetBinWidth(jbin)*sum_sim_proj.GetBinWidth(ibin)
                sum_sim_proj.SetBinContent(ibin,sum_sim_proj.GetBinContent(ibin)+bin_additive)
        Format_Graph(sum_sim_proj,21,0,2,3,2)
        for ibin in range(1,sum_sim_proj.GetNbinsX()+1):
            sum_sim_proj.SetBinError(ibin, 0.1*sum_sim_proj.GetBinContent(ibin))
        sum_sim_proj.Draw("same H")
        legends[-1].AddEntry(sum_sim_proj,"sum+BG","l")
        Format_Legend(legends[-1],0.08)
        legends[-1].Draw()

if not write_html:c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757897828377" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897828377(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1000,1000)
skip_thermal = 0
sim_dca = [3,4,5,8]
legends =[]
iOpt = 1
add_bg = 1
shift = 6
keffs = [1,1,1,1,2e-7,0.5e-7,1,1,3e-7,1,1,1]
for icentr in range(1,2):

    legends.append(root.TLegend(0.5,0.65,0.98,0.98,centralities[icentr]))
    for ihist in range(2,3):
        c0.cd(1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][ihist][icentr],"DCA_T^{e^{+}e^{-}} (#mum)", "dN/DCA_{T}^{e^{+}e^{-}} (#mum^{-1}) in PHENIX acceptance",0.17,0.17,0.01,0.01,0.05,0.05,21,1.5,4,3,4,0.99,1.55)
        hists_read[iOpt][ihist][icentr].GetXaxis().SetRangeUser(0,1000)
        hists_read[iOpt][ihist][icentr].GetYaxis().SetRangeUser(2e-14,9e-8)
        hists_read[iOpt][ihist][icentr].Draw("")
        hists_read[iOpt][ihist+1][icentr].SetFillColorAlpha(4,0.6)
        hists_read[iOpt][ihist+1][icentr].Draw("same e2")
        legends.append(root.TLegend(0.2,0.91,0.99,0.98,"Run 2014 "+centralities[icentr]+" Au+Au #sqrt{s_{NN}} = 200 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends[-1].Draw()
        legends.append(root.TLegend(0.2, 0.86, 0.99, 0.89, "|y^{e}|<0.35, p_{T}^{e }>0.4 GeV, p_{T}^{ee}>0.8 GeV"))
        Format_Legend(legends[-1],0.04,12)
        legends.append(root.TLegend(0.16,0.83,0.65,0.95))
        Format_Legend(legends[-1],0.045,12)
        legends[-1].SetNColumns(2)
        legends[-1].AddEntry(hists_read[iOpt][ihist][icentr],"FG-0.97#timesBG","p")
        legends[-1].AddEntry(hists_read[iOpt][10][icentr],"0.03#timesBG","p")
        legends[-1].Draw()
        legends.append(root.TLegend(0.33,0.74,0.6,0.86))
        Format_Hist_total(hists_read[iOpt][ihist][icentr],"DCA_{T}^{e^{+}e^{-}} (#mum)", "dN/DCA_{T}^{e^{+}e^{-}} (#mum^{-1}) in acceptance",0.17,0.17,0.01,0.01,0.05,0.05,21,1.5,4,3,4,0.99,1.65)
        Format_Legend(legends[-1],0.035,12)
        legends[-1].AddEntry(0,"1.5<|m_{ee}|<2.5","")
        legends[-1].AddEntry(0,"|y^{e}|<0.35","")
        legends[-1].Draw()
        legends.append(root.TLegend(0.6,0.64+0.06*skip_thermal,0.99,0.90))
        Format_Legend(legends[-1],0.035,12)


        sum_sim_proj = hists_sim[isim][icentr].ProjectionX(hists_sim[len(sim_file_names)-1][icentr].GetName()+"_proj1_dca_tot_new") 
        sum_sim_proj.Add(sum_sim_proj,-1)
        for isim in sim_dca:
            if skip_thermal and isim == 8: continue
            sim_proj = hists_sim[isim][icentr].ProjectionX(hists_sim[isim][icentr].GetName()+"_proj1_new_dca",23,55,1,25) 
            sim_proj.Scale(0.)
            h_stat = copycat_hist(hists_sim[isim][icentr+18])
            h_stat.Scale(0.)
            for jsim in range(1,3):
                sim_proj.Add(hists_sim[isim][shift+jsim].ProjectionX(hists_sim[isim][shift+jsim].GetName()+f"_proj1_new_{isim}{iOpt}",23,55,1,25),
                             10./sim_proj.GetBinWidth(1)*keffs[isim])
                h_stat.Add(hists_sim[isim][jsim+18])
            sim_proj.Scale(1./h_stat.GetEntries())
            #sim_proj.Scale(10./sim_proj.GetBinWidth(1)/hists_sim[isim][icentr+18].GetEntries()*keffs[icentr][isim])
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim])
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")
        
        if add_bg:
            Format_Graph(hists_read[iOpt][10][icentr],21,1.5,root.kCyan,3,root.kCyan)
            hists_read[iOpt][10][icentr].Draw("same")
            #sum_sim_proj.Add(hists_read[iOpt][9][icentr],1)
            for ibin in range(1,sum_sim_proj.GetNbinsX()+1):
                jbin = hists_read[iOpt][10][icentr].FindBin(sum_sim_proj.GetBinCenter(ibin))
                bin_additive= hists_read[iOpt][10][icentr].GetBinContent(jbin)#/hists_read[iOpt][10][icentr].GetBinWidth(jbin)*sum_sim_proj.GetBinWidth(ibin)
                sum_sim_proj.SetBinContent(ibin,sum_sim_proj.GetBinContent(ibin)+bin_additive)
        Format_Graph(sum_sim_proj,21,0,2,3,2)
        for ibin in range(1,sum_sim_proj.GetNbinsX()+1):
            sum_sim_proj.SetBinError(ibin, 0.1*sum_sim_proj.GetBinContent(ibin))
        sum_sim_proj.Draw("same H")
        legends[-1].AddEntry(sum_sim_proj,"sum+BG","l")
        Format_Legend(legends[-1],0.08)
        legends[-1].Draw()

if not write_html:c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757897828880" style="width: 1000px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897828880(Core) {
# ...

# %%
File_check = 0
infile = root.TFile.Open(sim_file_path+sim_file_names[File_check], "read")
hist_pt_mother= infile.Get("hist_pt_mother")
hist_pt_mother.SetDirectory(root.nullptr)
hist_pt_mother_weight = infile.Get("hist_pt_mother_weight")
hist_pt_mother_weight.SetDirectory(root.nullptr)
infile.Close()
N_ev_sim = []
for icentr in range(0,5):
    N_ev_sim.append(hist_pt_mother.ProjectionX(f"hist_pt_mother_proj_{icentr}", icentr+1, (icentr+1)).GetEntries())
    #if not write_html: print(f"{centralities[icentr]}: {N_ev_sim[-1]}")

# %%
c00 = root.TCanvas(f"c00",f"c00",1550,900)
c00.Divide(3,2)
Ncolls_auau = [771,282.4,82.6,12.1,3,257]
hagedorn = []
for icentr in range(5):
    c00.cd(1+icentr)
    hagedorn.append(root.TF1(f"hagedorn_{icentr}", " 2 * 3.1415 * x * [0] * pow( exp(-[1]*x-[2]*x*x)+x/[3] , -[4])", 100, 0.4, 10))
    hagedorn[-1].SetParameters(377, 0.356, 0.068, 0.7,8.25)
    hagedorn[-1].SetParameters(504.5*Ncolls_auau[icentr]/Ncolls_auau[-1], 0.5169, 0.1626, 0.7366, 8.274)
    hagedorn[-1].SetLineWidth(3)
    hagedorn[-1].SetLineColor(2)
    hist_pt_mother_porj = hist_pt_mother_weight.ProjectionX(f"hist_pt_mother_weight_proj_{icentr}", icentr+1, (icentr+1))
    Format_Hist_total(hist_pt_mother_porj, title_x="p_{T}, GeV/c", title_y="dN/dp_{T}, GeV/c^{-1}", offset_y=1.1, Mcolor=1, Msize =1, Lcolor=1, Lwidth=5)
    hist_pt_mother_porj.Draw("P")
    for ibin in range(1, hist_pt_mother_porj.GetNbinsX()+1):
        hist_pt_mother_porj.SetBinError(ibin, (hist_pt_mother_porj.GetBinContent(ibin)**0.5+0.2*hist_pt_mother_porj.GetBinContent(ibin))/hist_pt_mother_porj.GetBinWidth(ibin)/50e6*10)
        hist_pt_mother_porj.SetBinContent(ibin, hist_pt_mother_porj.GetBinContent(ibin)/hist_pt_mother_porj.GetBinWidth(ibin)/N_ev_sim[icentr]*10/0.01174)
    #hist_pt_mother_porj.Fit(hagedorn, "R", "", 0.4, 10)
    hagedorn[-1].Draw("same")
    root.gPad.SetLogy()
c00.Draw()
# Out:
# <div id="root_plot_1757897829194" style="width: 1550px; height: 900px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897829194(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1000,3000)
c0.Divide(1,3)
masses = [1,0,2]
legends =[]
loc_names = ["#new ML","#old ML", "new pt ML"]
for icentr, ii in zip([0,1,5], [0,1,2]):

    legends.append(root.TLegend(0.6,0.6,0.99,0.99,centralities[icentr]))

    for iOpt in masses:
        c0.cd(ii+1)
        root.gPad.SetLogy()
        if iOpt==masses[0] :
            Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        #hists_read[iFile][type_loc][itype].GetZaxis().SetRange(ibin0,ibin1)
        hists_read[iOpt][0][icentr].SetMarkerColorAlpha(colors0[iOpt],(10-1)/10.)
        hists_read[iOpt][0][icentr].SetLineColorAlpha  (colors0[iOpt],(10-1)/10.)
        if iOpt==masses[0] :hists_read[iOpt][0][icentr].Draw("")
        else: hists_read[iOpt][0][icentr].Draw("same")
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],loc_names[iOpt],"pl")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(colors0[iOpt],0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
    
        #legends[-1].AddEntry(0,"","a")
    Format_Legend(legends[-1],0.08,12)
    legends[-1].Draw()

if not write_html: c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757897909682" style="width: 1000px; height: 3000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757897909682(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1400,1100)
c0.Divide(3,2)
masses = [0,1]
legends =[]
loc_names = ["#phi dc","#phi vtx"]
for icentr in range(0,N_centr):

    legends.append(root.TLegend(0.6,0.6,0.99,0.99,centralities[icentr]))

    for iOpt in masses:
        c0.cd(icentr+1)
        root.gPad.SetLogy()
        if iOpt==masses[0] :
            Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        #hists_read[iFile][type_loc][itype].GetZaxis().SetRange(ibin0,ibin1)
        hists_read[iOpt][0][icentr].SetMarkerColorAlpha(colors0[iOpt],(10-1)/10.)
        hists_read[iOpt][0][icentr].SetLineColorAlpha  (colors0[iOpt],(10-1)/10.)
        if iOpt==masses[0] :hists_read[iOpt][0][icentr].Draw("")
        else: hists_read[iOpt][0][icentr].Draw("same")
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],loc_names[iOpt],"pl")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(colors0[iOpt],0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
    
        #legends[-1].AddEntry(0,"","a")
    Format_Legend(legends[-1],0.08,12)
    legends[-1].Draw()

if not write_html: c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757705767432" style="width: 1400px; height: 1100px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757705767432(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1400,1000)
c0.Divide(3,2)
sim_dca = [1,3,4,5,8]
keffs = [[1,1,1,1,abs_norm_cc,abs_norm_bb,1,1,2e-7,1,1],[1,2,2,5e1,1e-7,2e-8,1,1,2e-5,1,1],[1,1,1,7e1,2e-7,2e-8,1,1,0e-6,1,1],\
         [1,1,1,1e2,2e-7,2e-8,1,1,5e-7,1,1],[1,1,1,1e2,2e-7,2e-8,1,1,2e-6,1,1],[1,1,1,5e1,1e-7,2e-8,1,1,3e-7,1,1]]
legends =[]
iOpt = 1
for icentr in range(0,N_centr):

    legends.append(root.TLegend(0.4,0.75,0.98,0.98,centralities[icentr]))
    for ihist in range(2,3):
        c0.cd(icentr+1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        
        hists_read[iOpt][ihist][icentr].SetMarkerColorAlpha(colors[ihist],(10-1)/10.)
        hists_read[iOpt][ihist][icentr].SetLineColorAlpha  (colors[ihist],(10-1)/10.)
        hists_read[iOpt][ihist][icentr].Draw("")

        hists_read[iOpt][ihist+1][icentr].SetFillColorAlpha(colors[ihist],0.4)
        hists_read[iOpt][ihist+1][icentr].Draw("same e2")

        legends[-1].AddEntry(hists_read[iOpt][ihist][icentr],Hists_names[ihist]+" "+Opt_names[iOpt],"pl")
        

        sum_sim_proj = hists_sim[len(sim_file_names)-1][icentr].ProjectionX(hists_sim[len(sim_file_names)-1][icentr].GetName()+"_proj_dca_tot") 
        sum_sim_proj.Add(sum_sim_proj,-1)
        for isim in sim_dca:
            sim_proj = hists_sim[isim][icentr+0].ProjectionX(hists_sim[isim][icentr+0].GetName()+"_proj_dca",1,55,3,25) 
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim])
            sim_proj.Scale(10./sim_proj.GetBinWidth(1)/hists_sim[isim][icentr+18].GetEntries()*keffs[icentr][isim])
            if icentr==3:  print(f"{hists_sim[isim][icentr+6].Integral()*keffs[icentr][isim]/Br_to_ee[isim]:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{hists_sim[isim][icentr+6].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]*100:.0f}%, {part_names[isim]}")
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")
        
        Format_Graph(sum_sim_proj,21,0,colors[isim+1],3,colors[isim+1])
        sum_sim_proj.Draw("same H")
        Format_Legend(legends[-1],0.08)
        legends[-1].Draw()

if not write_html:c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# 9.27E+01, 8.24E-01 11245%, #phi #rightarrow ee & #etaee
# 6.02E+01, 1.49E-03 4055486%, J/#psi  #rightarrow ee
# 1.28E+01, 2.35E-01 5458%, c#bar{c} #rightarrow ee
# 4.87E-01, 1.96E-02 2489%, b#bar{b} #rightarrow ee
# 2.13E+01, 1.96E+01 109%, QGP
# <div id="root_plot_1757705767650" style="width: 1400px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757705767650(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1400,1000)
c0.Divide(3,2)
sim_dca = [1,3,4,5,8]
legends =[]
iOpt = 1
for icentr in range(0,N_centr):

    legends.append(root.TLegend(0.4,0.75,0.98,0.98,centralities[icentr]))
    for ihist in range(4,5):
        c0.cd(icentr+1)
        root.gPad.SetLogy()
        Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        
        hists_read[iOpt][ihist][icentr].SetMarkerColorAlpha(colors[ihist],(10-1)/10.)
        hists_read[iOpt][ihist][icentr].SetLineColorAlpha  (colors[ihist],(10-1)/10.)
        hists_read[iOpt][ihist][icentr].Draw("")

        hists_read[iOpt][ihist+1][icentr].SetFillColorAlpha(colors[ihist],0.4)
        hists_read[iOpt][ihist+1][icentr].Draw("same e2")

        legends[-1].AddEntry(hists_read[iOpt][ihist][icentr],Hists_names[ihist]+" "+Opt_names[iOpt],"pl")
        

        sum_sim_proj = hists_sim[len(sim_file_names)-1][icentr].ProjectionX(hists_sim[len(sim_file_names)-1][icentr].GetName()+"_proj_dca_tot_jpsi") 
        sum_sim_proj.Add(sum_sim_proj,-1)
        for isim in sim_dca:
            sim_proj = hists_sim[isim][icentr+6].ProjectionX(hists_sim[isim][icentr+6].GetName()+"_proj_dca_jpsi",56,64,1,25) 
            Format_Graph(sim_proj,21+isim,0,colors[isim],3,colors[isim])
            sim_proj.Scale(10./sim_proj.GetBinWidth(1)/hists_sim[isim][icentr+18].GetEntries()*keffs[icentr][isim])
            if icentr==3:  print(f"{hists_sim[isim][icentr+6].Integral()*keffs[icentr][isim]/Br_to_ee[isim]:.2E}, {dNdy_centr[icentr][isim]:.2E}",\
                                 f"{hists_sim[isim][icentr+6].Integral()*keffs[icentr][isim]/Br_to_ee[isim]/dNdy_centr[icentr][isim]*100:.0f}%, {part_names[isim]}")
            sum_sim_proj.Add(sim_proj,1)
            sim_proj.Draw("same H")
            legends[-1].AddEntry(sim_proj,part_names[isim],"l")
        
        Format_Graph(sum_sim_proj,21,0,colors[isim+1],3,colors[isim+1])
        sum_sim_proj.Draw("same H")
        Format_Legend(legends[-1],0.08)
        legends[-1].Draw()

if not write_html:c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# 9.27E+01, 8.24E-01 11245%, #phi #rightarrow ee & #etaee
# 6.02E+01, 1.49E-03 4055486%, J/#psi  #rightarrow ee
# 1.28E+01, 2.35E-01 5458%, c#bar{c} #rightarrow ee
# 4.87E-01, 1.96E-02 2489%, b#bar{b} #rightarrow ee
# 2.13E+01, 1.96E+01 109%, QGP
# <div id="root_plot_1757705767844" style="width: 1400px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757705767844(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1400,1000)
c0.Divide(3,2)

legends =[]
iOpt = 0
for icentr in range(0,N_centr):

    legends.append(root.TLegend(0.4,0.75,0.98,0.98,centralities[icentr]))
    for ihist in range(2,6,2):
        c0.cd(icentr+1)
        root.gPad.SetLogy()
        if ihist==2 :
            Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        #hists_read[iFile][type_loc][itype].GetZaxis().SetRange(ibin0,ibin1)
        hists_read[iOpt][ihist][icentr].SetMarkerColorAlpha(colors[ihist],(10-1)/10.)
        hists_read[iOpt][ihist][icentr].SetLineColorAlpha  (colors[ihist],(10-1)/10.)
        if ihist==2 :hists_read[iOpt][ihist][icentr].Draw("")
        else: hists_read[iOpt][ihist][icentr].Draw("same")
        hists_read[iOpt][ihist+1][icentr].SetFillColorAlpha(colors[ihist],0.4)
        hists_read[iOpt][ihist+1][icentr].Draw("same e2")
        legends[-1].AddEntry(hists_read[iOpt][ihist][icentr],Hists_names[ihist]+" "+Opt_names[iOpt],"pl")
    
    Format_Legend(legends[-1],0.08)
    legends[-1].Draw()

if not write_html:c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757705767979" style="width: 1400px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757705767979(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1400,1000)
c0.Divide(3,2)

legends =[]
ihist = 2
N_loc_options = 5
for icentr in range(0,N_centr):

    legends.append(root.TLegend(0.6,0.6,0.99,0.99,centralities[icentr]))
    for iOpt in range(0,3):
        c0.cd(icentr+1)
        root.gPad.SetLogy()
        if iOpt==0 :
            Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        #hists_read[iFile][type_loc][itype].GetZaxis().SetRange(ibin0,ibin1)
        hists_read[iOpt][ihist][icentr].SetMarkerColorAlpha(colors[iOpt],(10-1)/10.)
        hists_read[iOpt][ihist][icentr].SetLineColorAlpha  (colors[iOpt],(10-1)/10.)
        if iOpt==0 :hists_read[iOpt][ihist][icentr].Draw("")
        else: hists_read[iOpt][ihist][icentr].Draw("same")
        hists_read[iOpt][ihist+1][icentr].SetFillColorAlpha(colors[iOpt],0.4)
        hists_read[iOpt][ihist+1][icentr].Draw("same e2")
        legends[-1].AddEntry(hists_read[iOpt][ihist][icentr],Opt_names[iOpt],"pl")
    
    for iOpt in range(1+N_loc_options,N_options):
        legends[-1].AddEntry(0,"","a")
    Format_Legend(legends[-1],0.08)
    legends[-1].Draw()

if not write_html:c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757705768109" style="width: 1400px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757705768109(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1400,1100)
c0.Divide(3,2)
masses = [1,0,2]
legends =[]
for icentr in range(0,N_centr):

    legends.append(root.TLegend(0.6,0.6,0.99,0.99,centralities[icentr]))

    for iOpt in masses:
        c0.cd(icentr+1)
        root.gPad.SetLogy()
        if iOpt==masses[0] :
            Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        #hists_read[iFile][type_loc][itype].GetZaxis().SetRange(ibin0,ibin1)
        hists_read[iOpt][0][icentr].SetMarkerColorAlpha(colors0[iOpt],(10-1)/10.)
        hists_read[iOpt][0][icentr].SetLineColorAlpha  (colors0[iOpt],(10-1)/10.)
        if iOpt==masses[0] :hists_read[iOpt][0][icentr].Draw("")
        else: hists_read[iOpt][0][icentr].Draw("same")
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],Opt_names[iOpt],"pl")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(colors0[iOpt],0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
    
        #legends[-1].AddEntry(0,"","a")
    Format_Legend(legends[-1],0.08,12)
    legends[-1].Draw()

if not write_html: c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757705768237" style="width: 1400px; height: 1100px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757705768237(Core) {
# ...

# %%
c0 = root.TCanvas(f"c0",f"c0",1400,1100)
c0.Divide(3,2)
masses = [1,2,1,0,0,0]
legends =[]
for icentr in range(0,N_centr):

    legends.append(root.TLegend(0.6,0.6,0.99,0.99,centralities[icentr]))

    for iiOpt in range(1):
        iOpt = masses[icentr]
        c0.cd(icentr+1)
        root.gPad.SetLogy()
        if True:
            Format_Hist_total(hists_read[iOpt][0][icentr],"m_{ee}, GeV","dN/dm_{ee}, GeV^{-1}",0.17,0.13,0.01,0.01,0.07,0.06,21,1.5,4,3,4,0.85,1.24)
        #hists_read[iFile][type_loc][itype].GetZaxis().SetRange(ibin0,ibin1)
        hists_read[iOpt][0][icentr].SetMarkerColorAlpha(colors0[3],(10-1)/10.)
        hists_read[iOpt][0][icentr].SetLineColorAlpha  (colors0[3],(10-1)/10.)
        if True :hists_read[iOpt][0][icentr].Draw("")
        else: hists_read[iOpt][0][icentr].Draw("same")
        legends[-1].AddEntry(hists_read[iOpt][0][icentr],"final","pl")
        hists_read[iOpt][1][icentr].SetFillColorAlpha(colors0[3],0.4)
        hists_read[iOpt][1][icentr].Draw("same e2")
    
        #legends[-1].AddEntry(0,"","a")
    Format_Legend(legends[-1],0.08,12)
    legends[-1].Draw()

if not write_html: c0.Draw()
#c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr.png")
# Out:
# <div id="root_plot_1757705768369" style="width: 1400px; height: 1100px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1757705768369(Core) {
# ...
