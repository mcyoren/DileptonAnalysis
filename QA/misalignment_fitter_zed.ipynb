# %%
# %run input/Format.ipynb
import ROOT as root
from array import array
root.gErrorIgnoreLevel = root.kFatal
import multiprocess as mp
root.gStyle.SetOptFit(1111)
# %jsroot on
# Out:
# /home/yoren/.local/lib/python3.10/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# Welcome to JupyROOT 6.30/06

# %%
iOption0 = 0
# !rm output/misalignment/?/*
iType = 2
sim = 0
Min_Entries = 10000

# %%
N_zed_bins = 8
N_files = 1
N_arm = 2
N_layer = 8
rebin = 1
if iOption0: rebin = 1
colors=[1,2,4,root.kGreen+2,root.kMagenta,root.kOrange+4,root.kGray,root.kCyan]
#file_path="input/NewHadron/rungroup/"
file_path="../VTXalignment/input/"
#file_name="my-17th_QA_19443_all"
file_name="my-m_ee_Run14AuAu_103rd_new_19927_255runs.root "
#m_ee_Run14AuAu_97th_new_19917_1065runs m_ee_Run14AuAu_103rd_new_19927_255runs
#m_ee_Run14AuAu_95th_new_19914_1055runs m_ee_Run14AuAu_96th_new_19915_203runs
#m_ee_Run14AuAu_94th_new_19913_757runs m_ee_Run14AuAu_93rd_new_19904_1054runs
full_path = file_path + file_name
#my-17th_QA_19443_all
#new 7 - only east, 8 - west 2 cm 1.5 gev, 9 - as 8 but 1 Gev; 10 - as 8 but 0.5;  11 -alg corrected;  12 - vtx moved; 13 - vtx and dc moved;  14 - standard
# 19 - sep charge, 20 - 1 iter, 21 - 2 iter, 22 - 3 iter 1.5 pt, 23 - 0.5 pt, 24 - 1.5 phiDC; 25 - 0.5, 26 3 iter 1.5, 27 - 0.5, 28 phi - the corr
hist_select_3D_names = ["dphi_phi0_pt_hist","dthe_the0_pt_hist"]
if iType == 1: hist_select_3D_names = ["dphi_phi0_init_hist","dthe_the0_init_hist","dphi_the0_init_hist","dthe_phi0_init_hist"]
if iType == 2: hist_select_3D_names = ["dphi_phi0_corr_hist","dthe_the0_corr_hist","dphi_the0_corr_hist","dthe_phi0_corr_hist"]
iOptamesX=["phi","the","the","phi"]
iOptamesY=["phi","the","phi","the"]

# %%
full_pahtes = ["input/NewHadron/my-m_ee_Run14AuAu_90th_new_19887_300runs.root","../sim/output/Newembed/align/jpsi_v1.root","input/NewHadron/my-m_ee_Run14AuAu_89th_new_19877_398runs.root",\
               "../sim/output/my-kek.root","output/Newembed/deltas/piminus_DCA_50M_V0.root"]
if sim: full_path=full_pahtes[sim-1]

# %%
hists_read = []

for ifile in range(N_files):
    infile = root.TFile.Open(full_path, "read")
    #print(f"Reading file {ifile} from {file_path+file_name+f'_rg{ifile}.root'}")
    hists_read_file = []
    for ilayer in range(N_layer):
        hist_select_3D0 = []
        NNN = 4
        for ihist in range(NNN):  
            hist_select_3D0.append(infile.Get(hist_select_3D_names[ihist]+f"_{ilayer%4}"))
            hist_select_3D0[-1].SetName(hist_select_3D0[-1].GetName()+f"_file{ifile}")
            hist_select_3D0[-1].SetDirectory(root.nullptr)
            if ilayer%4==2:
                hist_select_3D0[-1].Add(infile.Get(hist_select_3D_names[ihist]+f"_{ilayer%4+1}"))
        hists_read_file.append(hist_select_3D0)
    hists_read.append(hists_read_file)
infile.Close()

# %%
boards_tot = [[-0.099,0.099],[-0.099,0.099]]
boards_gaus = [[-0.051,0.052],[-0.051,0.052]]
boards_pol0 = [[-0.09,0.09],[-0.09,0.09]]

# %%
def misalignment_fitter(InHist, ilayer, iarm, jzed):
    N_gaus=1

    hist_phi_bin = InHist.ProjectionY("kek")

    ibinz0 = 1+int(ilayer/4)+iarm*2
    ibinz1 = 1+int(ilayer/4)+iarm*2

    tot_entries = dphi_porj = InHist.ProjectionX(f"dphi_tot_{ilayer}_{iarm}_{jzed}", 1, 120, ibinz0, ibinz1).GetEntries()
    N_bins_X = InHist.ProjectionX(f"dphi_tot1_{ilayer}_{iarm}_{jzed}", 1, 120, ibinz0, ibinz1).GetNbinsX()

    phi_local =  array( 'd' )
    phi_local_err =  array( 'd' )

    Mean_local =  array( 'd' )
    Sigma_local =  array( 'd' )
    Mean_local_err =  array( 'd' )
    Sigma_local_err =  array( 'd' )

    int_fg_local =  array( 'd' )
    int_bg_local =  array( 'd' )

    N_bins = hist_phi_bin.GetNbinsX()
    N_iter = int(N_bins/rebin)

    limits = [jzed, jzed+1]
    if jzed == -1: 
        limits = [0, N_zed_bins]
 
    for iphi in range(N_iter):
        c1 = root.TCanvas(f"c1_{ilayer}_{iphi}_{iarm}_{jzed}",f"c1_{ilayer}_{iphi}_{iarm}_{jzed}",720,360)

        ibiny0 = iphi*rebin+1
        ibiny1 = (iphi+1)*rebin

        dphi_porj = InHist.ProjectionX(f"dphi_hist_{ilayer}_{iphi}_{iarm}_{jzed}", ibiny0, ibiny1, ibinz0, ibinz1)
        dphi_porj.Add(dphi_porj, -1)
        for ized in range(limits[0], limits[1]):
            loc_proj = InHist.ProjectionX(f"dphi_hist_{ilayer}_{iphi}_{iarm}_{ized}_{jzed}", ibiny0, ibiny1, ibinz0 + ized*4, ibinz1 + ized*4)
            dphi_porj.Add(loc_proj)

        if dphi_porj.GetEntries() < Min_Entries:
            continue

        phi = 0.5* (hist_phi_bin.GetBinCenter(ibiny0) + hist_phi_bin.GetBinCenter(ibiny1))
        phi_err = rebin*hist_phi_bin.GetBinWidth(ibiny0)*0.5

        dphi_porj.SetLineColor(1)

        par_tot = array( 'd', (3*N_gaus+3)*[2.] )
        g_gaus= root.TF1( f'g_gaus_{ilayer}_{iphi}_{iarm}_{jzed}', 'gaus',  boards_gaus[iarm][0], boards_gaus[iarm][1])
        #g_gaus2= root.TF1( f'g_gaus_2_{ilayer}_{iphi}', 'gaus',  boards_fit2[icentr][0]+central_bean_prev, boards_fit2[icentr][1]+central_bean_prev)#[0]/[2]/sqrt(2*3.14159)*exp(-0.5*pow((x-[1])/[2],2))
        g_pol = root.TF1( f'g_pol_{ilayer}_{iphi}_{iarm}_{jzed}', '[0]+[1]*x*(abs(x)/x-1)+[2]*x*(abs(x)/x+1)',  boards_pol0[iarm][0], boards_pol0[iarm][1])
        Format_Func(g_pol,3,2)

        total = root.TF1( f'total_{ilayer}_{iphi}_{iarm}_{jzed}', 'gaus(0)+[3]+[4]*x*(abs(x)/x-1)+[5]*x*(abs(x)/x+1)',boards_tot[iarm][0], boards_tot[iarm][1])
        Format_Func(total,2,6)

        g_gaus.SetParameter(1,0.)
        g_gaus.SetParameter(2,boards_tot[iarm][1])

        dphi_porj.Draw()
        dphi_porj.Fit( g_gaus, 'QR')
        #dphi_porj.Fit( g_gaus2, 'QR+' )
        dphi_porj.Fit( g_pol, 'QR+' )

        par_gaus = g_gaus.GetParameters()
        par_pol = g_pol.GetParameters()

        par_tot[0], par_tot[1], par_tot[2] = par_gaus[0], par_gaus[1], par_gaus[2]
        par_tot[3], par_tot[4], par_tot[5] = par_pol[0], par_pol[1], par_pol[1]

        total.SetParameters( par_tot )
        #total.SetParLimits(1,boards_tot[iarm][0]/10,boards_tot[iarm][1]/10)
        #total.SetParLimits(2,boards_fit[iarm][1]/10,2)
        
        dphi_porj.Draw()
        dphi_porj.Fit( total, 'QR' )

        par_tot = total.GetParameters()

        g_gaus= root.TF1( f'g_gaus_4_{ilayer}_{iphi}_{iarm}_{jzed}', 'gaus',  par_tot[1]-2*par_tot[2], par_tot[1]+2*par_tot[2])

        Format_Func(g_gaus,3,4)

        par_gaus[0], par_gaus[1], par_gaus[2] = par_tot[0], par_tot[1], par_tot[2]
        par_pol[0], par_pol[1], par_pol[2] = par_tot[3], par_tot[4], par_tot[5]
        g_gaus.SetParameters(par_gaus)
        g_pol.SetParameters(par_pol)

        g_gaus.Draw('same')
        g_pol.Draw('same')

        if abs(total.GetParameter(1))>0.15 or total.GetNDF()<50 or (total.GetParameter(2)>0.0075 or total.GetParameter(2)<0.002 ): continue

        phi_local.append(phi)
        phi_local_err.append(phi_err)

        Mean_local.append(total.GetParameter(1))
        Sigma_local.append(total.GetParameter(2))
        Mean_local_err.append(total.GetParError(1)+total.GetParameter(2)*0.05+abs(total.GetParameter(2))*(dphi_porj.GetEntries()*total.GetNDF()/tot_entries)**(-0.5))
        Sigma_local_err.append(total.GetParError(2))


        int_fg_local.append(g_gaus.Integral(total.GetParameter(1)-2*total.GetParameter(2),total.GetParameter(1)+2*total.GetParameter(2)))
        int_bg_local.append(g_pol.Integral(total.GetParameter(1)-2*total.GetParameter(2),total.GetParameter(1)+2*total.GetParameter(2)))
            
        #m2_pos.Draw("same") m2_neg.Draw("same")

        c1.SaveAs(f"output/misalignment/{iOption0}/fit_{ilayer}_{iarm}_{iphi}_{jzed}.png" )

    return [Mean_local, Mean_local_err, Sigma_local, Sigma_local_err,phi_local,phi_local_err, int_fg_local, int_bg_local]

# %%
def misalignment_layer_fitter(jzed):
    out_hists = []
    for ilayer in range(N_layer):
        out_hists1 = []
        for iarm in range(N_arm):
            out_hists1.append(misalignment_fitter(hists_read[0][ilayer][iOption0], ilayer, iarm, jzed))
        out_hists.append(out_hists1)
    return out_hists

# %%
Ntr = N_zed_bins+1

pool = mp.Pool(Ntr)
with pool:
    output_array = pool.map(misalignment_layer_fitter,  [i for i in range(-1,N_zed_bins)])
pool.close()

# %%
Means, Mean_errs, Sigmas, Sigma_errs, phi_arr, phi_arr_err, Int_FG, Int_BG = [], [], [], [], [], [], [], []
for irg in range(N_zed_bins+1):
    Means1, Mean_errs1, Sigmas1, Sigma_errs1, phi_arr1, phi_arr_err1, Int_FG1, Int_BG1 = [], [], [], [], [], [], [], []
    for ilayer in range(N_layer):
        Means0, Mean_errs0, Sigmas0, Sigma_errs0, phi_arr0, phi_arr_err0, Int_FG0, Int_BG0 = [], [], [], [], [], [], [], []
        for iarm in range(N_arm):
            Means0.append(output_array[irg][ilayer][iarm][0])
            Mean_errs0.append(output_array[irg][ilayer][iarm][1])
            Sigmas0.append(output_array[irg][ilayer][iarm][2])
            Sigma_errs0.append(output_array[irg][ilayer][iarm][3])
            phi_arr0.append(output_array[irg][ilayer][iarm][4])
            phi_arr_err0.append(output_array[irg][ilayer][iarm][5])
            Int_FG0.append(output_array[irg][ilayer][iarm][6])
            Int_BG0.append(output_array[irg][ilayer][iarm][7])
        Means1.append(Means0)
        Mean_errs1.append(Mean_errs0)
        Sigmas1.append(Sigmas0)
        Sigma_errs1.append(Sigma_errs0)
        phi_arr1.append(phi_arr0)
        phi_arr_err1.append(phi_arr_err0)
        Int_FG1.append(Int_FG0)
        Int_BG1.append(Int_BG0)
    Means.append(Means1)
    Mean_errs.append(Mean_errs1)
    Sigmas.append(Sigmas1)
    Sigma_errs.append(Sigma_errs1)
    phi_arr.append(phi_arr1)
    phi_arr_err.append(phi_arr_err1)
    Int_FG.append(Int_FG1)
    Int_BG.append(Int_BG1)

# %%
root.gStyle.SetOptFit(0000)

# %%
types = ["emc_r_dphi_","emc_min_r_dphi_","emc_cnt_dphi_","emc_r_dz_","emc_min_r_dz_","emc_cnt_dz_"]
fit_functions = []

for irg in range(N_zed_bins+1):
    fit_functions0 = []
    for ilayer in range(N_layer):
        fit_functions1 = []
        for iarm in range(N_arm):
            fit_functions1.append(root.TF1(f"fit_functions_sigma_{ilayer}_{irg}_{iarm}","[0]*sin(x)+[1]*cos(x)+[2]",-1.5,4.5))
            fit_functions1[-1].SetParameter(0,0.001)
            fit_functions1[-1].SetParameter(1,0.001)
            fit_functions1[-1].SetParameter(2,0.001)
            fit_functions1[-1].SetLineColor(colors[ilayer%8])
        fit_functions0.append(fit_functions1)
    fit_functions.append(fit_functions0)

# %%
iarm = 0
h2=[]
c2 = root.TCanvas(f"c2_{iarm}",f"c2_{iarm}",1000,400*int(max(N_zed_bins/2+1,1)))
c2.Divide(2,int(max(N_zed_bins/2+1,1)))
g_mean = []
min0, max0 = -0.025, 0.025
x0, x1 = 1.5, 4
if iOption0>0 and iOption0<3: x0, x1 = 1., 2.
legends =[]
for ized in range(N_zed_bins+1):
    if False and ized ==1 :
        iarm = 1
        if iOption0==0: x0, x1 = -1, 1.5
    g_mean_rg = []
    c2.cd(ized+1)
    h2.append(Format_Pad_old( x0, x1, min0+0.008, max0, f"{iOptamesX[iOption0]}0 (rad)", f"#LT d{iOptamesY[iOption0]} #GT", 1.1, 1.1, 0.06, 0.05, "",0.15,0.15,0.,0.1,f"h_{iarm}_{ized}"))
    h2[-1].Draw()
    legends.append(root.TLegend(0.25,0.5,0.85,0.9))
    legends[-1].SetFillColorAlpha(0,0)
    legends[-1].SetLineWidth(0)
    legends[-1].SetNColumns(2)
    for ilayer in range(0,N_layer,1):
        if ilayer%4!=2: continue  # Skip layers 0,1,4,5
        N_phi = len(phi_arr[ized][ilayer][iarm])
        if N_phi<1: continue
        #print(N_phi,len (phi_arr[ilayer][ized][iarm]), len(Means[ilayer][ized][iarm]),len(phi_arr_err[ilayer][ized][iarm]),len(Mean_errs[ilayer][ized][iarm]))
        g_mean_layer = root.TGraphErrors(N_phi, phi_arr[ized][ilayer][iarm], Means[ized][ilayer][iarm],phi_arr_err[ized][ilayer][iarm],Mean_errs[ized][ilayer][iarm])
        Format_Graph(g_mean_layer,20+int(ilayer/4),1, colors[ilayer%8], 3, colors[ilayer%8],1,1)
        if ized > 0:
            fit_functions[ized][ilayer][iarm].SetParameters(fit_functions[0][ilayer][iarm].GetParameters())
            fit_functions[ized][ilayer][iarm].FixParameter(2, fit_functions[0][ilayer][iarm].GetParameter(2))
            fit_functions[ized][ilayer][iarm].SetParLimits(0, fit_functions[0][ilayer][iarm].GetParameter(0)-0.007, fit_functions[0][ilayer][iarm].GetParameter(0)+0.007)
            fit_functions[ized][ilayer][iarm].SetParLimits(1, fit_functions[0][ilayer][iarm].GetParameter(1)-0.007, fit_functions[0][ilayer][iarm].GetParameter(1)+0.007)

        g_mean_layer.Fit(fit_functions[ized][ilayer][iarm],"Q","",x0+0.2-0.2*iOption0, x1-0.2+0.2*iOption0)
        g_mean_layer.Draw('P')
        if ilayer<4: legends[-1].AddEntry(g_mean_layer,f"pos layer {ilayer}","p")
        else: legends[-1].AddEntry(g_mean_layer,f"neg layer {ilayer}","p")
        g_mean_rg.append(g_mean_layer)
    legends[-1].Draw()
    g_mean.append(g_mean_rg)
c2.Draw()
c2.SaveAs(f"output/misalignment/note/mean_{iType}_{iOption0}.pdf")
# Out:
# <div id="root_plot_1752936263753" style="width: 1000px; height: 2000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1752936263753(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":996,"fYtoAbsPixelk":1972.00005,"fYtoPixelk":1972.00005,"fYtoPixel":-1972,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":996,"fVtoAbsPixelk":1972.00005,"fVtoPixelk":1972,"fVtoPixel":-1972,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00100401606425703,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-5.0709939148073e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c2_0","fTitle":"c2_0","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":10,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":996,"fCh":1972,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239 ...

# %%
iarm = 1
h2=[]
c3 = root.TCanvas(f"c3_{iarm}",f"c3_{iarm}",1000,400*int(max(N_zed_bins/2+1,1)))
c3.Divide(2,int(max(N_zed_bins/2+1,1)))
g_mean1 = []
min0, max0 = -0.015, 0.015
x0, x1 = -1, 1.5
if iOption0>0 and iOption0<3: x0, x1 = 1., 2.
legends =[]
for ized in range(N_zed_bins+1):
    g_mean_rg1 = []
    c3.cd(ized+1)
    h2.append(Format_Pad_old( x0, x1, min0+0.008, max0, f"{iOptamesX[iOption0]}0 (rad)", f"#LT d{iOptamesY[iOption0]} #GT", 1.1, 1.1, 0.06, 0.05, "",0.15,0.15,0.,0.1,f"h_{iarm}_{ized}"))
    h2[-1].Draw()
    legends.append(root.TLegend(0.25,0.5,0.85,0.9))
    legends[-1].SetFillColorAlpha(0,0)
    legends[-1].SetLineWidth(0)
    legends[-1].SetNColumns(2)
    for ilayer in range(0,N_layer,1):
        if ilayer%4!=2: continue  # Skip layers 0,1,4,5
        N_phi = len(phi_arr[ized][ilayer][iarm])
        if N_phi<1: continue
        #print(N_phi,len (phi_arr[ilayer][ized][iarm]), len(Means[ilayer][ized][iarm]),len(phi_arr_err[ilayer][ized][iarm]),len(Mean_errs[ilayer][ized][iarm]))
        g_mean_layer1 = root.TGraphErrors(N_phi, phi_arr[ized][ilayer][iarm], Means[ized][ilayer][iarm],phi_arr_err[ized][ilayer][iarm],Mean_errs[ized][ilayer][iarm])
        Format_Graph(g_mean_layer1,20+int(ilayer/4),1, colors[ilayer%8], 3, colors[ilayer%8],1,1)
        if ized > 0:
            fit_functions[ized][ilayer][iarm].SetParameters(fit_functions[0][ilayer][iarm].GetParameters())
            fit_functions[ized][ilayer][iarm].FixParameter(2, fit_functions[0][ilayer][iarm].GetParameter(2))
            fit_functions[ized][ilayer][iarm].SetParLimits(0, fit_functions[0][ilayer][iarm].GetParameter(0)-0.007, fit_functions[0][ilayer][iarm].GetParameter(0)+0.007)
            fit_functions[ized][ilayer][iarm].SetParLimits(1, fit_functions[0][ilayer][iarm].GetParameter(1)-0.007, fit_functions[0][ilayer][iarm].GetParameter(1)+0.007)
        g_mean_layer1.Fit(fit_functions[ized][ilayer][iarm],"Q","",x0+0.2-0.2*iOption0, x1-0.2+0.2*iOption0 )
        g_mean_layer1.Draw('P')
        if ilayer<4: legends[-1].AddEntry(g_mean_layer1,f"pos layer {ilayer}","p")
        else: legends[-1].AddEntry(g_mean_layer1,f"neg layer {ilayer}","p")
        g_mean_rg1.append(g_mean_layer1)
    legends[-1].Draw()
    g_mean1.append(g_mean_rg1)
c3.Draw()
c3.SaveAs(f"output/misalignment/mean_{iarm}_{iOption0}.png")
# Out:
# <div id="root_plot_1752936264074" style="width: 1000px; height: 2000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1752936264074(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":996,"fYtoAbsPixelk":1972.00005,"fYtoPixelk":1972.00005,"fYtoPixel":-1972,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":996,"fVtoAbsPixelk":1972.00005,"fVtoPixelk":1972,"fVtoPixel":-1972,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00100401606425703,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-5.0709939148073e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c3_1","fTitle":"c3_1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":10,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":996,"fCh":1972,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239 ...

# %%
delta_x0 = array('d', [])
delta_x0_err = array('d', [])
delta_x1 = array('d', [])
delta_x1_err = array('d', [])
z_means = array('d', [])
z_means_err = array('d', [])
ilayer = 2
fit_functions_zed = []
zed_colors = [root.kRed, root.kBlue, root.kPink, root.kViolet, root.kGreen+2, root.kOrange+4, root.kGray, root.kCyan]
for ized in range(2):
    for iarm in range(N_arm):
        fit_functions_zed.append(root.TF1(f"fit_functions_zed_{ized}_{iarm}","[0]+[1]*x",-12,12))
        fit_functions_zed[-1].SetLineColor(zed_colors[2*iarm + ized])
for ized in range(1,N_zed_bins+1):
    z_means.append(-12 +ized*3 - 1.5)
    z_means_err.append(1.5)
    delta_x0.append((fit_functions[ized][ilayer][0].GetParameter(0) + fit_functions[ized][ilayer+4][0].GetParameter(0) - fit_functions[0][ilayer][0].GetParameter(0) - fit_functions[0][ilayer+4][0].GetParameter(0))/2)
    delta_x0_err.append(fit_functions[ized][ilayer][0].GetParError(0))
    delta_x1.append((fit_functions[ized][ilayer][1].GetParameter(0) + fit_functions[ized][ilayer+4][1].GetParameter(0) - fit_functions[0][ilayer][1].GetParameter(0) - fit_functions[0][ilayer+4][1].GetParameter(0))/2)
    delta_x1_err.append(fit_functions[ized][ilayer][1].GetParError(0))
g_delta_x0 = root.TGraphErrors(N_zed_bins, z_means, delta_x0, z_means_err, delta_x0_err)
g_delta_x1 = root.TGraphErrors(N_zed_bins, z_means, delta_x1, z_means_err, delta_x1_err)
Format_Graph(g_delta_x0, 20, 1, root.kRed, 3, root.kRed, 1, 1)
Format_Graph(g_delta_x1, 20, 1, root.kBlue, 3, root.kBlue, 1, 1)
g_delta_x0.SetTitle(f"Delta x vs z; z (cm); #Delta x (cm)")
g_delta_x1.SetTitle(f"Delta x vs z; z (cm); #Delta x (cm)")
c4 = root.TCanvas("c4","c4",800,600)
g_delta_x0.SetMaximum(  0.003 )
g_delta_x0.SetMinimum( -0.003 )
g_delta_x0.Draw("AP")
g_delta_x1.Draw("P same")
g_delta_x0.Fit(fit_functions_zed[0],"Q","", -12, 0)
g_delta_x0.Fit(fit_functions_zed[1],"Q+","",   0, 12)
g_delta_x1.Fit(fit_functions_zed[2],"Q","", -12, 0)
g_delta_x1.Fit(fit_functions_zed[3],"Q+","",  0, 12)
c4.Draw()
# Out:
# <div id="root_plot_1752936264235" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1752936264235(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-18.0000002682209,"fY1":-0.00375000005587936,"fX2":18.0000002682209,"fY2":0.00375000005587936,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":22.1111107816299,"fYtoAbsPixelk":286.00005,"fYtoPixelk":286.00005,"fYtoPixel":-76266.6655302047,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-18.0000002682209,"fPixeltoXk":-18.0000002682209,"fPixeltoX":0.0452261313271883,"fAbsPixeltoYk":0.00375000005587936,"fPixeltoYk":-0.00375000005587936,"fPixeltoY":-1.31118883072705e-5,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-14.4,"fUymin":-0.003,"fUxmax":14.4,"fUymax":0.003,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c4","fTitle":"c4","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;2 ...

# %%
##printing in c++  format result of fitting with fit_functions_zed
if not iOption0: print("const double delta_x_zed_DC_VTX_fit[2][2][2] = {")
else: print("const double delta_x_zed_DC_VTX_fit_theta[2][2][2][2] = {")
for iarm in range(N_arm):
    print("    {")
    for ized in range(2):
        print(f"        {{{fit_functions_zed[2*iarm + ized].GetParameter(0):.6f}, {fit_functions_zed[2*iarm + ized].GetParameter(1):.6f}}},")
    print("    },")
print("};")
# Out:
# const double delta_x_zed_DC_VTX_fit[2][2][2] = {
#     {
#         {0.000141, 0.000035},
#         {-0.000060, 0.000036},
#     },
#     {
#         {0.002167, 0.000409},
#         {-0.000414, 0.000077},
#     },
# };

# %%
delta_y0 = array('d', [])
delta_y0_err = array('d', [])
delta_y1 = array('d', [])
delta_y1_err = array('d', [])
z_means = array('d', [])
z_means_err = array('d', [])
ilayer = 2
fit_functions_zed1 = []
zed_colors = [root.kRed, root.kBlue, root.kPink, root.kViolet, root.kGreen+2, root.kOrange+4, root.kGray, root.kCyan]
for ized in range(2):
    for iarm in range(N_arm):
        fit_functions_zed1.append(root.TF1(f"fit_functions_zed_{ized}_{iarm}","[0]+[1]*x",-12+ized*12,0+ized*12))
        fit_functions_zed1[-1].SetLineColor(zed_colors[2*iarm + ized])
for ized in range(1,N_zed_bins+1):
    z_means.append(-12 +ized*3 - 1.5)
    z_means_err.append(1.5)
    delta_y0.append((fit_functions[ized][ilayer][0].GetParameter(1) + fit_functions[ized][ilayer+4][0].GetParameter(1) - fit_functions[0][ilayer][0].GetParameter(1) - fit_functions[0][ilayer+4][0].GetParameter(1))/2)
    delta_y0_err.append(fit_functions[ized][ilayer][0].GetParError(1))
    delta_y1.append((fit_functions[ized][ilayer][1].GetParameter(1) + fit_functions[ized][ilayer+4][1].GetParameter(1) - fit_functions[0][ilayer][1].GetParameter(1) - fit_functions[0][ilayer+4][1].GetParameter(1))/2)
    delta_y1_err.append(fit_functions[ized][ilayer][1].GetParError(1))
g_delta_y0 = root.TGraphErrors(N_zed_bins, z_means, delta_y0, z_means_err, delta_y0_err)
g_delta_y1 = root.TGraphErrors(N_zed_bins, z_means, delta_y1, z_means_err, delta_y1_err)
Format_Graph(g_delta_y0, 20, 1, root.kRed, 3, root.kRed, 1, 1)
Format_Graph(g_delta_y1, 20, 1, root.kBlue, 3, root.kBlue, 1, 1)
g_delta_y0.SetTitle(f"Delta y vs z; z (cm); #Delta y (cm)")
g_delta_y1.SetTitle(f"Delta y vs z; z (cm); #Delta y (cm)")
c4 = root.TCanvas("c4","c4",800,600)
g_delta_y0.SetMaximum(  0.009 )
g_delta_y0.SetMinimum( -0.009 )
g_delta_y0.Draw("AP")
g_delta_y1.Draw("P same")
g_delta_y0.Fit(fit_functions_zed1[0],"Q","", -12, 0)
g_delta_y0.Fit(fit_functions_zed1[1],"Q+","",   0, 12)
g_delta_y1.Fit(fit_functions_zed1[2],"Q","", -12, 0)
g_delta_y1.Fit(fit_functions_zed1[3],"Q+","",  0, 12)
c4.Draw()
# Out:
# <div id="root_plot_1752936264477" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1752936264477(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-18.0000002682209,"fY1":-0.0112500001676381,"fX2":18.0000002682209,"fY2":0.0112500001676381,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":22.1111107816299,"fYtoAbsPixelk":286.00005,"fYtoPixelk":286.00005,"fYtoPixel":-25422.2218434016,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-18.0000002682209,"fPixeltoXk":-18.0000002682209,"fPixeltoX":0.0452261313271883,"fAbsPixeltoYk":0.0112500001676381,"fPixeltoYk":-0.0112500001676381,"fPixeltoY":-3.93356649218114e-5,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-14.4,"fUymin":-0.009,"fUxmax":14.4,"fUymax":0.009,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c4","fTitle":"c4","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:1 ...

# %%
##printing in c++  format result of fitting with fit_functions_zed
if not iOption0: print("const double delta_y_zed_DC_VTX_fit[2][2][2] = {")
else: print("const double delta_y_zed_DC_VTX_fit_theta[2][2][2][2] = {")
for iarm in range(N_arm):
    print("    {")
    for ized in range(2):
        print(f"        {{{fit_functions_zed1[2*iarm + ized].GetParameter(0):.6f}, {fit_functions_zed1[2*iarm + ized].GetParameter(1):.6f}}},")
    print("    },")
print("};")
# Out:
# const double delta_y_zed_DC_VTX_fit[2][2][2] = {
#     {
#         {0.000027, 0.000025},
#         {-0.000291, 0.000078},
#     },
#     {
#         {-0.000902, -0.000169},
#         {0.000398, -0.000078},
#     },
# };

# %%
if True:
    ilayer = 2
    print(f"const float "+iOptamesX[iOption0]+f"_offset_params[{N_zed_bins}][{N_arm}][2][3] = "+"{")
    for irg in range(1,N_zed_bins+1):
        print("    {")
        for iarm in range(N_arm):
            iirg = irg
            #if iOption0 == 1 and irg>4 and iarm == 0:
            #    if irg < 8: iirg = 4
            #    elif irg < 10: iirg = 11
            print("        {")     
            print("            {"+f"{round(fit_functions[iirg][ilayer+0][iarm].GetParameter(0),6)}, {round(fit_functions[iirg][ilayer+0][iarm].GetParameter(1),6)}, {round(fit_functions[iirg][ilayer+0][iarm].GetParameter(2),6)}"+"},")
            print("            {"+f"{round(fit_functions[iirg][ilayer+4][iarm].GetParameter(0),6)}, {round(fit_functions[iirg][ilayer+4][iarm].GetParameter(1),6)}, {round(fit_functions[iirg][ilayer+4][iarm].GetParameter(2),6)}"+"},")
            print("        },")  
        print("    },")   
    print("};")
# Out:
# const float phi_offset_params[8][2][2][3] = {
#     {
#         {
#             {-4.9e-05, -0.002759, -0.002492},
#             {-0.001213, 0.002438, 0.002658},
#         },
#         {
#             {-0.002317, -0.002611, 0.002157},
#             {-0.004462, -0.000941, 0.00268},
#         },
#     },
#     {
#         {
#             {0.000522, -0.002087, -0.002492},
#             {0.000161, 0.002375, 0.002658},
#         },
#         {
#             {0.000741, -0.002747, 0.002157},
#             {0.002279, -0.002356, 0.00268},
#         },
#     },
#     {
#         {
#             {-9e-05, -0.002248, -0.002492},
#             {2.4e-05, 0.002374, 0.002658},
#         },
#         {
#             {0.000969, -0.003399, 0.002157},
#             {0.001794, -0.0032, 0.00268},
#         },
#     },
#     {
#         {
#             {-8.5e-05, -0.002059, -0.002492},
#             {-2.7e-05, 0.002338, 0.002658},
#         },
#         {
#             {0.000323, -0.003101, 0.002157},
#             {0.001551, -0.003468, 0.00268},
#         },
#     },
#     {
#         {
#             {0.000204, -0.002046, -0.002492},
#             {-4.9e-05, 0.001889, 0.002658},
#         },
#         {
#             {-0.000299, -0.002396, 0.002157},
#             {0.001354, -0.003479, 0.00268},
#         },
#     },
#     {
#         {
#             {-0.000263, -0.001694, -0.002492},
#             {-0.000278, 0.002085, 0.002658},
#         },
#         {
#             {7.4e-05, -0.001981, 0.002157},
#             {0.000157, -0.002912, 0.00268},
#         },
#     },
#     {
#         {
#             {0.000503, -0.001065, -0.002492},
#             {0.000268, 0.002579, 0.002658},
#         },
#         {
#             {-0.000302, -0.001746, 0.002157},
#             {-2.5e-05, -0.003448, 0.00268},
#         },
#     },
#     {
#         {
#             {1.2e-05, -0.001347, -0.002492},
#             {0.000486, 0.002187, 0.002658},
#         },
#         {
#             {0.002314, -0.00268, 0.002157},
#             {0.001384, -0.004884, 0.00268},
#         },
#     },
# };

# %%
if False:
    print(f"const float "+iOptames[iOption0]+f"_offset_param0[{N_rg}][{N_arm}][2][4] = "+"{")
    for irg in range(N_rg):
        print("    {")
        for iarm in range(N_arm):
            print("        {")     
            print("            {"+f"{round(fit_functions[0][irg][iarm].GetParameter(0),6)}, {round(fit_functions[1][irg][iarm].GetParameter(0),6)}, {round(fit_functions[2][irg][iarm].GetParameter(0),6)}, {round(fit_functions[3][irg][iarm].GetParameter(0),6)}"+"},")
            print("            {"+f"{round(fit_functions[4][irg][iarm].GetParameter(0),6)}, {round(fit_functions[5][irg][iarm].GetParameter(0),6)}, {round(fit_functions[6][irg][iarm].GetParameter(0),6)}, {round(fit_functions[7][irg][iarm].GetParameter(0),6)}"+"},")
            print("        },")  
        print("    },")   
    print("};")
    print(f"const float "+iOptames[iOption0]+f"_offset_param1[{N_rg}][{N_arm}][2][4] = "+"{")
    for irg in range(N_rg):
        print("    {")
        for iarm in range(N_arm):
            print("        {")     
            print("            {"+f"{round(fit_functions[0][irg][iarm].GetParameter(1),6)}, {round(fit_functions[1][irg][iarm].GetParameter(1),6)}, {round(fit_functions[2][irg][iarm].GetParameter(1),6)}, {round(fit_functions[3][irg][iarm].GetParameter(1),6)}"+"},")
            print("            {"+f"{round(fit_functions[4][irg][iarm].GetParameter(1),6)}, {round(fit_functions[5][irg][iarm].GetParameter(1),6)}, {round(fit_functions[6][irg][iarm].GetParameter(1),6)}, {round(fit_functions[7][irg][iarm].GetParameter(1),6)}"+"},")
            print("        },")  
        print("    },")   
    print("};")
    print(f"const float "+iOptames[iOption0]+f"_offset_param2[{N_rg}][{N_arm}][2][4] = "+"{")
    for irg in range(N_rg):
        print("    {")
        for iarm in range(N_arm):
            print("        {")     
            print("            {"+f"{round(fit_functions[0][irg][iarm].GetParameter(2),6)}, {round(fit_functions[1][irg][iarm].GetParameter(2),6)}, {round(fit_functions[2][irg][iarm].GetParameter(2),6)}, {round(fit_functions[3][irg][iarm].GetParameter(2),6)}"+"},")
            print("            {"+f"{round(fit_functions[4][irg][iarm].GetParameter(2),6)}, {round(fit_functions[5][irg][iarm].GetParameter(2),6)}, {round(fit_functions[6][irg][iarm].GetParameter(2),6)}, {round(fit_functions[7][irg][iarm].GetParameter(2),6)}"+"},")
            print("        },")  
        print("    },")   
    print("};")

# %%
if False:
    ilayer, ilayer1 = 1, 5
    if iOption0: print(f"const float the_offset_params[{N_rg}][{N_arm}][3] = "+"{")
    else: print(f"const float phi_offset_params[{N_rg}][{N_arm}][3] = "+"{")
    for irg in range(N_rg):
        print("    {")
        for iarm in range(N_arm):
            print("        {"+f"{round(fit_functions[ilayer][irg][iarm].GetParameter(0)+fit_functions[ilayer1][irg][iarm].GetParameter(0),6)}, \
    {round(fit_functions[ilayer][irg][iarm].GetParameter(1)+fit_functions[ilayer1][irg][iarm].GetParameter(1),6)}, \
    {round(fit_functions[ilayer][irg][iarm].GetParameter(2)+fit_functions[ilayer1][irg][iarm].GetParameter(2),6)}"+"},")
        print("    },")   
    print("};")

# %%
iarm = 0
h4=[]
c4 = root.TCanvas(f"c4_{iarm}",f"c4_{iarm}",1000,400*int(N_zed_bins/2+1))
c4.Divide(2,int(N_zed_bins/2+1))
min0, max0 = -0.015, 0.015
x0, x1 = 1.5, 4
if iOption0>0 and iOption0<3: x0, x1 = 1., 2.
legends =[]
g_sigma = []
for irg in range(N_zed_bins+1):
    c4.cd(irg+1)
    h4.append(Format_Pad_old( x0, x1, 0, max0, f"{iOptamesX[iOption0]}0 (rad)", f"sigma d{iOptamesY[iOption0]}", 1.1, 1.1, 0.06, 0.05, "",0.15,0.15,0.,0.1,f"h_{iarm}_{irg}"))
    h4[-1].Draw()
    legends.append(root.TLegend(0.25,0.5,0.85,0.9))
    legends[-1].SetFillColorAlpha(0,0)
    legends[-1].SetLineWidth(0)
    legends[-1].SetNColumns(2)
    g_sigma_rg = []
    for ilayer in range(0,N_layer):
        N_phi = len(phi_arr[irg][ilayer][iarm])
        if N_phi<1: continue
        #print(N_phi,len (phi_arr[ilayer][irg][iarm]), len(Means[ilayer][irg][iarm]),len(phi_arr_err[ilayer][irg][iarm]),len(Mean_errs[ilayer][irg][iarm]))
        g_sigma_layer = root.TGraphErrors(N_phi, phi_arr[irg][ilayer][iarm], Sigmas[irg][ilayer][iarm],phi_arr_err[irg][ilayer][iarm],Sigma_errs[irg][ilayer][iarm])
        Format_Graph(g_sigma_layer,20+int(ilayer/4),1, colors[ilayer], 3, colors[ilayer],1,1)
        g_sigma_layer.Fit("pol0","Q","")
        g_sigma_layer.GetFunction("pol0").SetLineColor(colors[ilayer])
        g_sigma_layer.Draw('P')
        if ilayer<4: legends[-1].AddEntry(g_sigma_layer,f"pos layer {ilayer}","p")
        else: legends[-1].AddEntry(g_sigma_layer,f"neg layer {ilayer}","p")
        g_sigma_rg.append(g_sigma_layer)
    g_sigma.append(g_sigma_rg)
    legends[-1].Draw()
c4.Draw()
c4.SaveAs(f"output/misalignment/sigma_{iarm}_{iOption0}.png")
# Out:
# <div id="root_plot_1752936265552" style="width: 1000px; height: 2000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1752936265552(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":996,"fYtoAbsPixelk":1972.00005,"fYtoPixelk":1972.00005,"fYtoPixel":-1972,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":996,"fVtoAbsPixelk":1972.00005,"fVtoPixelk":1972,"fVtoPixel":-1972,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00100401606425703,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-5.0709939148073e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c4_0","fTitle":"c4_0","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":10,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":996,"fCh":1972,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239 ...

# %%
iarm = 1
h4=[]
c5 = root.TCanvas(f"c5_{iarm}",f"c5_{iarm}",1000,400*int(N_rg/2))
c5.Divide(2,int(N_rg/2))
min0, max0 = -0.015, 0.015
x0, x1 =-1, 1.5
if iOption0>0 and iOption0<3: x0, x1 = 1., 2.
legends =[]
g_sigma = []
for irg in range(N_rg):
    c5.cd(irg+1)
    h4.append(Format_Pad_old( x0, x1, 0, max0, f"{iOptamesX[iOption0]}0 (rad)", f"sigma d{iOptamesY[iOption0]}", 1.1, 1.1, 0.06, 0.05, "",0.15,0.15,0.,0.1,f"h_{iarm}_{irg}"))
    h4[-1].Draw()
    legends.append(root.TLegend(0.25,0.5,0.85,0.9))
    legends[-1].SetFillColorAlpha(0,0)
    legends[-1].SetLineWidth(0)
    legends[-1].SetNColumns(2)
    g_sigma_rg = []
    for ilayer in range(0,N_layer):
        N_phi = len(phi_arr[irg][ilayer][iarm])
        if N_phi<1: continue
        #print(N_phi,len (phi_arr[ilayer][irg][iarm]), len(Means[ilayer][irg][iarm]),len(phi_arr_err[ilayer][irg][iarm]),len(Mean_errs[ilayer][irg][iarm]))
        g_sigma_layer = root.TGraphErrors(N_phi, phi_arr[irg][ilayer][iarm], Sigmas[irg][ilayer][iarm],phi_arr_err[irg][ilayer][iarm],Sigma_errs[irg][ilayer][iarm])
        Format_Graph(g_sigma_layer,20+int(ilayer/4),1, colors[ilayer], 3, colors[ilayer],1,1)
        g_sigma_layer.Fit("pol0","Q","")
        g_sigma_layer.GetFunction("pol0").SetLineColor(colors[ilayer])
        g_sigma_layer.Draw('P')
        if ilayer<4: legends[-1].AddEntry(g_sigma_layer,f"pos layer {ilayer}","p")
        else: legends[-1].AddEntry(g_sigma_layer,f"neg layer {ilayer}","p")
        g_sigma_rg.append(g_sigma_layer)
    g_sigma.append(g_sigma_rg)
    legends[-1].Draw()
c5.Draw()
c5.SaveAs(f"output/misalignment/sigma_{iarm}_{iOption0}.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 iarm = 1
#       2 h4=[]
# ----> 3 c5 = root.TCanvas(f"c5_{iarm}",f"c5_{iarm}",1000,400*int(N_rg/2))
#       4 c5.Divide(2,int(N_rg/2))
#       5 min0, max0 = -0.015, 0.015
#
# NameError: name 'N_rg' is not defined

# %%
#printing out in c++ format but making them same size of 11 elements and filling spaces with 0 phi_arr[ized][ilayer][iarm], Means[ized][ilayer][iarm]
if True:
    print(f"const float phi_offsets_DC_sim[{1}][{N_layer}][{N_arm}][11] = "+"{")
    for irg in range(1):
        print("    {")
        for ilayer in range(N_layer):
            print("        {")
            for iarm in range(N_arm):
                if len(phi_arr[irg][ilayer][iarm]) < 11:
                    print("            {"+", ".join(["0.,"]*(11-len(phi_arr[irg][ilayer][iarm])))+f"{', '.join([f'{x:.6f}' for x in phi_arr[irg][ilayer][iarm]])}}},")
                else:
                    print("            {"+", ".join([f"{x:.6f}" for x in phi_arr[irg][ilayer][iarm]])+"},")
            print("        },")
        print("    },")
    print("};")
    print(f"const float offsets_DC_sim[{1}][{N_layer}][{N_arm}][11] = "+"{")
    for irg in range(1):
        print("    {")
        for ilayer in range(N_layer):
            print("        {")
            for iarm in range(N_arm):
                if len(Means[irg][ilayer][iarm]) < 11:
                    print("            {"+", ".join(["0.,"]*(11-len(Means[irg][ilayer][iarm])))+f"{', '.join([f'{x:.6f}' for x in Means[irg][ilayer][iarm]])}}},")
                else:
                    print("            {"+", ".join([f"{x:.6f}" for x in Means[irg][ilayer][iarm]])+"},")
            print("        },")
        print("    },")
    print("};")
# Out:
# const float phi_offsets_DC_sim[1][8][2][11] = {
#     {
#         {
#             {2.119500, 2.276500, 2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500},
#             {-0.706500, -0.549500, -0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500},
#         },
#         {
#             {2.119500, 2.276500, 2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500},
#             {-0.706500, -0.549500, -0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500},
#         },
#         {
#             {2.119500, 2.276500, 2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500},
#             {-0.706500, -0.549500, -0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500},
#         },
#         {
#             {2.119500, 2.276500, 2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500},
#             {-0.706500, -0.549500, -0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500},
#         },
#         {
#             {2.276500, 2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500, 3.846500},
#             {0.,-0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500, 1.020500},
#         },
#         {
#             {0.,2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500, 3.846500},
#             {0.,-0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500, 1.020500},
#         },
#         {
#             {2.276500, 2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500, 3.846500},
#             {0.,-0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500, 1.020500},
#         },
#         {
#             {2.276500, 2.433500, 2.590500, 2.747500, 2.904500, 3.061500, 3.218500, 3.375500, 3.532500, 3.689500, 3.846500},
#             {0.,-0.392500, -0.235500, -0.078500, 0.078500, 0.235500, 0.392500, 0.549500, 0.706500, 0.863500, 1.020500},
#         },
#     },
# };
# const float offsets_DC_sim[1][8][2][11] = {
#     {
#         {
#             {0.000713, 0.000853, 0.000586, -0.000351, -0.000138, 0.000403, -0.000652, -0.001230, -0.001524, -0.001407, -0.000760},
#             {-0.001769, -0.000919, 0.001096, -0.000349, -0.000750, 0.000538, -0.000773, -0.000785, -0.001100, -0.000599, -0.000716},
#         },
#         {
#             {0.000022, 0.000561, -0.000644, -0.000721, -0.000262, 0.000320, -0.000879, -0.001197, -0.001436, -0.001236, -0.000386},
#             {-0.001642, -0.001262, 0.000617, -0.000207, -0.000661, 0.000569, -0.000654, -0.000695, -0.001085, -0.000180, -0.000175},
#         },
#         {
#             {-0.001854, -0.000202, -0.001344, -0.001290, -0.000114, 0.000015, -0.000826, -0.001344, -0.000811, -0.000159, 0.000756},
#             {-0.000842, -0.001979, 0.000190, -0.000371, -0.000315, 0.000081, -0.000597, -0.000588, -0.000590, 0.000724, 0.000941},
#         },
#         {
#             {-0.002621, -0.000459, -0.001749, -0.001387, -0.000459, -0.000202, -0.000784, -0.001469, -0.000809, 0.000005, 0.000801},
#             {-0.001277, -0.002026, 0.000178, -0.000333, -0.000280, -0.000202, -0.000444, -0.000603, -0.000522, 0.000908, 0.001148},
#         },
#         {
#             {0.002420, 0.002735, 0.002280, 0.001632, 0.002012, 0.001261, 0.000231, 0.000401, 0.000334, 0.000155, 0.001238},
#             {0.,0.000744, 0.000814, 0.000555, 0.000576, 0.000362, 0.000714, 0.000908, 0.000710, -0.000254, 0.000654},
#         },
#         {
#             {0.,0.001431, 0.001663, 0.001421, 0.001795, 0.000991, 0.000132, 0.000258, 0.000346, 0.000860, 0.000877},
#             {0.,0.000219, 0.000705, 0.000514, 0.000463, 0.000152, 0.000743, 0.000837, 0.000987, 0.000117, 0.000646},
#         },
#         {
#             {0.000220, 0.000534, 0.000387, 0.000761, 0.001181, 0.000668, -0.000517, 0.000266, 0.000665, 0.001706, 0.000964},
#             {0.,-0.000503, -0.000054, 0.000213, 0.000048, 0.000226, 0.000661, 0.000538, 0.001314, 0.000713, 0.001406},
#         },
#         {
#             {-0.000231, -0.000029, 0.000105, 0.000129, 0.000738, 0.000557, -0.000809, 0.000090, 0.000673, 0.002060, 0.000398},
#             {0.,-0.000725, -0.000178, 0.000268, -0.000036, 0.000164, 0.000735, 0.000456, 0.001359, 0.000886, 0.001694},
#         },
#     },
# };
