# %%
# %run input/Format.ipynb
import ROOT as root
from array import array
root.gErrorIgnoreLevel = root.kFatal
# %jsroot on
# Out:
# /home/yoren/.local/lib/python3.10/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# Welcome to JupyROOT 6.30/06

# %%
iOption0 = 1
part = 0
N_loc_files = 2

# %%
N_centr = 5
N_pt = 1
colors=[1,2,4,root.kGreen+2,root.kMagenta,root.kOrange+4,root.kGray,root.kCyan]
central_bins = [0,20,60,80,20,40,40,60,60,80,80,100]
pt_boarders = [0.4,0.7,1.0,2.0,0,5.0,1.0,5.0,0.5,5]
file_path="../sim/output/invmass_embed/"
file_names=["bbbar_v1_10M.root","ccbar_v4_12M.root","jpsi_v6_10M.root","phi_v9_10M.root","../embed/photon_50M_embed_hagedorn_v8_secondhit.root","../embed/piminus_10M_embed_hagedorn_v0_truehit.root",\
            "../embed/piminus_10M_embed_hagedorn_v0_assoc_counter.root","../embed/photon_50M_embed_hagedorn_v8_secondhit.root"]
part_names = ["b#bar{b}","c#bar{c}","J/#psi","#phi","#gamma #rightarrow ee","#pi^{-}","#pi^{-}","#gamma #rightarrow ee"]
hist_mass_DCA_names = ["truehithist"]
hists_all = [hist_mass_DCA_names]
N_type = len(hists_all)
N_files = len(file_names)

# %%
hists_read = []

for iFile in range(N_files):
    infile = root.TFile.Open(file_path+file_names[iFile], "read")
    hists_emc_read0 = []
    for itype in range(N_type):
        hist_select_3D0 = []
        for ihist in range(len(hists_all[itype])):
            if iFile < 5: hist_select_3D0.append(infile.Get(hists_all[itype][ihist]))
            elif iFile == 5: hist_select_3D0.append(infile.Get("truehitsigmahist"))
            elif iFile == 6 or iFile == 7: hist_select_3D0.append(infile.Get("counter_assoc_eff_hist"))
            hist_select_3D0[-1].SetDirectory(root.nullptr)
            hist_select_3D0[-1].SetName(hist_select_3D0[-1].GetName()+f"{iFile}")
        hists_emc_read0.append(hist_select_3D0)
    hists_read.append(hists_emc_read0)

infile.Close()

# %%
ipt = 0
type_loc = 0 
N_dca_files = 4
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c0",f"c0",1400,450*N_dca_files)
c0.Divide(N_type_loc,N_dca_files)
for itype in range(N_type_loc):
    for iFile in range(0,N_dca_files):
        c0.cd(itype*N_dca_files+iFile+1)
        ibin0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(pt_boarders[2*ipt+0])
        ibin1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(pt_boarders[2*ipt+1])
        #hists_read[iFile][type_loc][itype].GetZaxis().SetRange(ibin0,ibin1)
        hists_read[iFile][type_loc][itype].Project3D("yx").Draw("colz")

#c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/qa_pt_centr_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/qa_pt_centr_0.png" for writing. Please check permissions.

# %%
type_loc =0
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c1",f"c1",700*2,450*2)
c0.Divide(2,2)
N_dca_files = 4
legends = []
for itype in range(N_type_loc):
    for iselect in range(4):
        max = 0
        legends.append(root.TLegend(0.61,0.6,0.75,0.98))
        Format_Legend(legends[-1],0.03)
        for iFile in range(0,N_dca_files):
            c0.cd(iselect+1)
            ibinY0 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+0])
            ibinY1 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+1])
            ibinZ0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+0])
            ibinZ1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+1])
            project = hists_read[iFile][type_loc][itype].ProjectionX(hists_read[iFile][type_loc][itype].GetName()+f"_X_{iselect}",ibinY0,ibinY1,ibinZ0,ibinZ1)
            project.Scale(1./project.Integral())
            project.SetMaximum(100)
            Unity_Line(0,10)
            for ibin in range(project.GetNbinsX()):
                if ibin <=4 : project.GetXaxis().SetBinLabel(ibin,f"{ibin-1}/3")
                else :       project.GetXaxis().SetBinLabel(ibin,f"{ibin-1-4}/4")
            Format_Hist_total(project, "N_{true}/N^{all}_{assoc.}", "prob. dens.", 0.15, 0.15, 0.01, 0.01,  .07,  0.06, 21,  2, iFile+1,  7,  iFile+1,  0.95, 1.08, "",  1,  1-0.15*iFile)
            project.GetXaxis().SetRange(project.FindBin(0),project.FindBin(9))
            root.gPad.SetLogy()
            if iFile == 0 :
                project.Draw("H")
                max = project.GetMaximum()
            else:
                project.Scale(max/project.GetMaximum())          
                project.Draw("H same")
            legends[-1].AddEntry(project,part_names[iFile],"l")
        legends[-1].Draw()
        legends.append(root.TLegend(0.21,0.78,0.45,0.98))
        Format_Legend(legends[-1],0.09)
        legends[-1].SetHeader("#splitline{"+f"{pt_boarders[2*(iselect%2)+0]}<pT<{pt_boarders[2*(iselect%2)+1]}"+"}{"+f"{central_bins[2*int(iselect/2)+0]}%-{central_bins[2*int(iselect/2)+1]}%"+"}")
        legends[-1].Draw()


c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/ghost_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/ghost_0.png" for writing. Please check permissions.
# <div id="root_plot_1728922617269" style="width: 1400px; height: 900px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1728922617269(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":872.00005,"fYtoPixelk":872.00005,"fYtoPixel":-872,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":872.00005,"fVtoPixelk":872,"fVtoPixel":-872,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00114678899082569,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":12.85714,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":872,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239; ...

# %%
type_loc =0
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c1",f"c1",700*2,450*2)
c0.Divide(2,2)
N_dca_files = 4
legends = []
for itype in range(N_type_loc):
    for iselect in range(4):
        max = 0
        legends.append(root.TLegend(0.61,0.6,0.75,0.98))
        Format_Legend(legends[-1],0.03)
        for iFile in range(3,5):
            c0.cd(iselect+1)
            ibinY0 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+0])
            ibinY1 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+1])
            ibinZ0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+0])
            ibinZ1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+1])
            project = hists_read[iFile][type_loc][itype].ProjectionX(hists_read[iFile][type_loc][itype].GetName()+f"_X_{iselect}",ibinY0,ibinY1,ibinZ0,ibinZ1)
            project.Scale(1./project.Integral())
            project.SetMaximum(100)
            Unity_Line(0,10)
            for ibin in range(project.GetNbinsX()):
                if ibin <=4 : project.GetXaxis().SetBinLabel(ibin,f"{ibin-1}/3")
                else :       project.GetXaxis().SetBinLabel(ibin,f"{ibin-1-4}/4")
            Format_Hist_total(project, "N_{true}/N^{all}_{assoc.}", "prob. dens.", 0.15, 0.15, 0.01, 0.01,  .07,  0.06, 21,  2, iFile+1,  7,  iFile+1,  0.95, 1.08, "",  1,  1-0.15*iFile)
            project.GetXaxis().SetRange(project.FindBin(0),project.FindBin(9))
            root.gPad.SetLogy()
            if iFile == 3 :
                project.Draw("H")
                max = project.GetMaximum()
            else:
                project.Scale(max/project.GetMaximum())          
                project.Draw("H same")
            legends[-1].AddEntry(project,part_names[iFile],"l")
        legends[-1].Draw()
        legends.append(root.TLegend(0.21,0.78,0.45,0.98))
        Format_Legend(legends[-1],0.09)
        legends[-1].SetHeader("#splitline{"+f"{pt_boarders[2*(iselect%2)+0]}<pT<{pt_boarders[2*(iselect%2)+1]}"+"}{"+f"{central_bins[2*int(iselect/2)+0]}%-{central_bins[2*int(iselect/2)+1]}%"+"}")
        legends[-1].Draw()


c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/ghost_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/ghost_0.png" for writing. Please check permissions.
# <div id="root_plot_1728922617594" style="width: 1400px; height: 900px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1728922617594(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":872.00005,"fYtoPixelk":872.00005,"fYtoPixel":-872,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":872.00005,"fVtoPixelk":872,"fVtoPixel":-872,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00114678899082569,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":12.85714,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":872,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239; ...

# %%
type_loc =0
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c1",f"c1",700*2,450*2)
c0.Divide(2,2)
N_dca_files = 4
legends = []
for itype in range(N_type_loc):
    for iselect in range(4):
        max = 0
        legends.append(root.TLegend(0.66,0.65,0.75,0.98))
        Format_Legend(legends[-1],0.03)
        for iFile in range(5,6):
            c0.cd(iselect+1)
            ibinY0 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+0])
            ibinY1 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+1])
            ibinZ0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+0])
            ibinZ1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+1])
            project = hists_read[iFile][type_loc][itype].ProjectionX(hists_read[iFile][type_loc][itype].GetName()+f"_X_{iselect}",ibinY0,ibinY1,ibinZ0,ibinZ1)
            project.Scale(5./project.Integral()/1.072)
            project.SetMaximum(1.5)
            project.SetMinimum(0.6)
            Unity_Line(0,10)
            for ibin in range(project.GetNbinsX()):
                if ibin%10 != 4 and ibin%10 != 9:
                    project.SetBinContent(ibin,0)
            project.Rebin(10)
            for ibin in range(project.GetNbinsX()+1):
                project.GetXaxis().SetBinLabel(ibin,f"{ibin+1}")
            Format_Hist_total(project, "simga", "N^{all}_{assoc.} norm to 1", 0.15, 0.15, 0.01, 0.01,  .07,  0.06, 21,  2, 4,  7,  4,  0.95, 1.08, "",  1,  1)
            project.GetXaxis().SetRange(project.FindBin(0),project.FindBin(49))
            #root.gPad.SetLogy()
            if iFile == 5 :
                project.Draw("H")
                max = project.GetMaximum()
            else:
                project.Scale(max/project.GetMaximum())          
                project.Draw("H same")
            legends[-1].AddEntry(project,part_names[iFile],"l")
        legends[-1].Draw()
        legends.append(root.TLegend(0.21,0.78,0.45,0.98))
        Format_Legend(legends[-1],0.09)
        legends[-1].SetHeader("#splitline{"+f"{pt_boarders[2*(iselect%2)+0]}<pT<{pt_boarders[2*(iselect%2)+1]}"+"}{"+f"{central_bins[2*int(iselect/2)+0]}%-{central_bins[2*int(iselect/2)+1]}%"+"}")
        legends[-1].Draw()


#c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/ghost_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/ghost_0.png" for writing. Please check permissions.

# %%
type_loc =0
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c1",f"c1",700*2,450*2)
c0.Divide(2,2)
N_dca_files = 4
legends = []
for itype in range(N_type_loc):
    for iselect in range(4):
        max = 0
        legends.append(root.TLegend(0.66,0.65,0.75,0.98))
        Format_Legend(legends[-1],0.03)
        for iFile in range(6,7):
            c0.cd(iselect+1)
            ibinY0 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+0])
            ibinY1 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+1])
            ibinZ0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+0])
            ibinZ1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+1])
            project = hists_read[iFile][type_loc][itype].ProjectionX(hists_read[iFile][type_loc][itype].GetName()+f"_X_{iselect}",ibinY0,ibinY1,ibinZ0,ibinZ1)
            project.Scale(1./project.GetBinContent(1))
            project.SetMaximum(1.1)
            project.SetMinimum(0.0)
            Unity_Line(0,30)
            for ibin in range(project.GetNbinsX()):
                if ibin%7 != 6:
                    project.SetBinContent(ibin,0)
            project.Rebin(7)
            for ibin in range(project.GetNbinsX()+1):
                project.GetXaxis().SetBinLabel(ibin,f"{6-ibin}")
            Format_Hist_total(project, "simga", "N^{all}_{assoc.} norm to 1", 0.15, 0.15, 0.01, 0.01,  .07,  0.06, 21,  2, 4,  7,  4,  0.95, 1.08, "",  1,  1)
            project.GetXaxis().SetRange(project.FindBin(1),project.FindBin(30))
            #root.gPad.SetLogy()
            if iFile == 6 :
                project.Draw("H")
                max = project.GetMaximum()
            else:
                project.Scale(max/project.GetMaximum())          
                project.Draw("H same")
            legends[-1].AddEntry(project,part_names[iFile],"l")
        legends[-1].Draw()
        legends.append(root.TLegend(0.21,0.78,0.45,0.98))
        Format_Legend(legends[-1],0.09)
        legends[-1].SetHeader("#splitline{"+f"{pt_boarders[2*(iselect%2)+0]}<pT<{pt_boarders[2*(iselect%2)+1]}"+"}{"+f"{central_bins[2*int(iselect/2)+0]}%-{central_bins[2*int(iselect/2)+1]}%"+"}")
        legends[-1].Draw()


c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/ghost_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/ghost_0.png" for writing. Please check permissions.
# <div id="root_plot_1728922617979" style="width: 1400px; height: 900px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1728922617979(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":872.00005,"fYtoPixelk":872.00005,"fYtoPixel":-872,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":872.00005,"fVtoPixelk":872,"fVtoPixel":-872,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00114678899082569,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":12.85714,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":872,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239; ...

# %%
type_loc =0
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c1",f"c1",700*2,450*2)
c0.Divide(2,2)
N_dca_files = 4
legends = []
for itype in range(N_type_loc):
    for iselect in range(4):
        max = 0
        legends.append(root.TLegend(0.55,0.65,0.75,0.98))
        Format_Legend(legends[-1],0.03)
        for iFile in range(7,8):
            c0.cd(iselect+1)
            ibinY0 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+0])
            ibinY1 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+1])
            ibinZ0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+0])
            ibinZ1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+1])
            project = hists_read[iFile][type_loc][itype].ProjectionX(hists_read[iFile][type_loc][itype].GetName()+f"_X_{iselect}",ibinY0,ibinY1,ibinZ0,ibinZ1)
            project.Scale(1./project.GetBinContent(1))
            project.SetMaximum(0.09)
            project.SetMinimum(0.0)
            Unity_Line(0,30)
            for ibin in range(project.GetNbinsX()):
                if ibin%7 != 4:
                    project.SetBinContent(ibin,0)
            project.Rebin(7)
            for ibin in range(project.GetNbinsX()+1):
                project.GetXaxis().SetBinLabel(ibin,f"{6-ibin}")
            Format_Hist_total(project, "simga", "N^{all}_{assoc.} norm to 1", 0.15, 0.15, 0.01, 0.01,  .07,  0.06, 21,  2, 5,  7,  5,  0.95, 1.08, "",  1,  1)
            project.GetXaxis().SetRange(project.FindBin(1),project.FindBin(25))
            #root.gPad.SetLogy()
            if iFile == 7 :
                project.Draw("H")
                max = project.GetMaximum()
            else:
                project.Scale(max/project.GetMaximum())          
                project.Draw("H same")
            legends[-1].AddEntry(project,part_names[iFile],"l")
        legends[-1].Draw()
        legends.append(root.TLegend(0.21,0.78,0.45,0.98))
        Format_Legend(legends[-1],0.09)
        legends[-1].SetHeader("#splitline{"+f"{pt_boarders[2*(iselect%2)+0]}<pT<{pt_boarders[2*(iselect%2)+1]}"+"}{"+f"{central_bins[2*int(iselect/2)+0]}%-{central_bins[2*int(iselect/2)+1]}%"+"}")
        legends[-1].Draw()


c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/ghost_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/ghost_0.png" for writing. Please check permissions.
# <div id="root_plot_1728922618163" style="width: 1400px; height: 900px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1728922618163(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":872.00005,"fYtoPixelk":872.00005,"fYtoPixel":-872,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":872.00005,"fVtoPixelk":872,"fVtoPixel":-872,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00114678899082569,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":12.85714,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":872,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239; ...

# %%
type_loc =0
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c1",f"c1",700*2,450*2)
c0.Divide(2,2)
N_dca_files = 4
legends = []
for itype in range(N_type_loc):
    for iselect in range(4):
        max = 0
        legends.append(root.TLegend(0.55,0.6,0.75,0.90))
        Format_Legend(legends[-1],0.03)
        for iFile in range(7,8):
            c0.cd(iselect+1)
            ibinY0 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+0])
            ibinY1 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+1])
            ibinZ0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+0])
            ibinZ1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+1])
            project = hists_read[iFile][type_loc][itype].ProjectionX(hists_read[iFile][type_loc][itype].GetName()+f"_Y_{iselect}",ibinY0,ibinY1,ibinZ0,ibinZ1)
            project.Scale(1./project.GetBinContent(1))
            project.SetMaximum(0.05)
            project.SetMinimum(0.0)
            Unity_Line(0,30)
            for ibin in range(project.GetNbinsX()):
                if ibin%7 != 0:
                    project.SetBinContent(ibin,0)
            project.Rebin(7)
            for ibin in range(project.GetNbinsX()+1):
                project.GetXaxis().SetBinLabel(ibin,f"{6-ibin}")
            #for ibin in range(project.GetNbinsX()+1):
            #    project.GetXaxis().SetBinLabel(ibin,f"{ibin+1}")
            Format_Hist_total(project, "simga", "N^{all}_{assoc.} norm to 1", 0.15, 0.15, 0.01, 0.08,  .07,  0.06, 21,  2, 5,  7,  5,  0.95, 1.08, "",  1,  1)
            project.GetXaxis().SetRange(project.FindBin(1),project.FindBin(25))
            #root.gPad.SetLogy()
            if iFile == 7 :
                project.Draw("H")
                max = project.GetMaximum()
            else:
                project.Scale(max/project.GetMaximum())          
                project.Draw("H same")
            legends[-1].AddEntry(project,part_names[iFile],"l")
        legends[-1].Draw()
        legends.append(root.TLegend(0.21,0.7,0.45,0.9))
        Format_Legend(legends[-1],0.09)
        legends[-1].SetHeader("#splitline{"+f"{pt_boarders[2*(iselect%2)+0]}<pT<{pt_boarders[2*(iselect%2)+1]}"+"}{"+f"{central_bins[2*int(iselect/2)+0]}%-{central_bins[2*int(iselect/2)+1]}%"+"}")
        legends[-1].Draw()


c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/ghost_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/ghost_0.png" for writing. Please check permissions.
# <div id="root_plot_1728922618329" style="width: 1400px; height: 900px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1728922618329(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":872.00005,"fYtoPixelk":872.00005,"fYtoPixel":-872,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":872.00005,"fVtoPixelk":872,"fVtoPixel":-872,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00114678899082569,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":12.85714,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":872,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239; ...

# %%
type_loc =0
N_type_loc= len(hists_all[type_loc])
c0 = root.TCanvas(f"c1",f"c1",700*2,450*2)
c0.Divide(2,2)
N_dca_files = 4
legends = []
for itype in range(N_type_loc):
    for iselect in range(4):
        max = 0
        legends.append(root.TLegend(0.55,0.6,0.75,0.90))
        Format_Legend(legends[-1],0.03)
        for iFile in range(7,8):
            c0.cd(iselect+1)
            ibinY0 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+0])
            ibinY1 = hists_read[iFile][type_loc][itype].ProjectionY().FindBin(pt_boarders[2*(iselect%2)+1])
            ibinZ0 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+0])
            ibinZ1 = hists_read[iFile][type_loc][itype].ProjectionZ().FindBin(central_bins[2*int(iselect/2)+1])
            project = hists_read[iFile][type_loc][itype].ProjectionX(hists_read[iFile][type_loc][itype].GetName()+f"_Z_{iselect}",ibinY0,ibinY1,ibinZ0,ibinZ1)
            project.Scale(1./project.GetBinContent(1))
            project.SetMaximum(0.05)
            project.SetMinimum(0.0)
            Unity_Line(0,30)
            for ibin in range(project.GetNbinsX()):
                if ibin%7 != 1:
                    project.SetBinContent(ibin,0)
            project.Rebin(7)
            for ibin in range(project.GetNbinsX()+1):
                project.GetXaxis().SetBinLabel(ibin,f"{6+1-ibin}")
            #for ibin in range(project.GetNbinsX()+1):
            #    project.GetXaxis().SetBinLabel(ibin,f"{ibin+1}")
            Format_Hist_total(project, "simga", "N^{all}_{assoc.} norm to 1", 0.15, 0.15, 0.01, 0.08,  .07,  0.06, 21,  2, 5,  7,  5,  0.95, 1.08, "",  1,  1)
            project.GetXaxis().SetRange(project.FindBin(10),project.FindBin(30))
            #root.gPad.SetLogy()
            if iFile == 7 :
                project.Draw("H")
                max = project.GetMaximum()
            else:
                project.Scale(max/project.GetMaximum())          
                project.Draw("H same")
            legends[-1].AddEntry(project,part_names[iFile],"l")
        legends[-1].Draw()
        legends.append(root.TLegend(0.21,0.7,0.45,0.9))
        Format_Legend(legends[-1],0.09)
        legends[-1].SetHeader("#splitline{"+f"{pt_boarders[2*(iselect%2)+0]}<pT<{pt_boarders[2*(iselect%2)+1]}"+"}{"+f"{central_bins[2*int(iselect/2)+0]}%-{central_bins[2*int(iselect/2)+1]}%"+"}")
        legends[-1].Draw()


c0.Draw()
c0.SaveAs(f"output/rich_emcal_qa/ghost_{ipt}.png")
# Out:
# python ERROR: cannot open image file "output/rich_emcal_qa/ghost_0.png" for writing. Please check permissions.
# <div id="root_plot_1728922618500" style="width: 1400px; height: 900px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1728922618500(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1396,"fYtoAbsPixelk":872.00005,"fYtoPixelk":872.00005,"fYtoPixel":-872,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1396,"fVtoAbsPixelk":872.00005,"fVtoPixelk":872,"fVtoPixel":-872,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.16332378223496e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00114678899082569,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":12.85714,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1396,"fCh":872,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;110:254,254,254;201:91,91,91;202:122,122,122;203:183,183,183;204:214,214,214;205:137,15,15;206:183,20,20;207:234,71,71;208:239,117,117;209:15,137,15;210:20,183,20;211:71,234,71;212:117,239,117;213:15,15,137;214:20,20,183;215:71,71,234;216:117,117,239;217:137,137,15;218:183,183,20;219:234,234,71;220:239,239,117;221:137,15,137;222:183,20,183;223:234,71,234;224:239,117,239; ...
